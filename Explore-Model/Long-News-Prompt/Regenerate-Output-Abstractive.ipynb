# %%
import pandas as pd

# %% [markdown]
# ### Load Dataset

# %%
# Data from tr-tpbs and is news with more than 3000 words.
# Same news but regenerated summary.

df_gemma = pd.read_csv(r'F:\Super AI SS4\Level 3 - INTERN\Jupyter Notebook\Try-prompt\Abstractive\try-many-time\many-time-gemma2.csv')

df_gemma_RAG = pd.read_csv(r'F:\Super AI SS4\Level 3 - INTERN\Jupyter Notebook\Try-prompt\Abstractive\try-many-time\many-time-gemma2-RAG.csv')

df_llama = pd.read_csv(r'F:\Super AI SS4\Level 3 - INTERN\Jupyter Notebook\Try-prompt\Abstractive\try-many-time\many-time-llama3.csv')

df_llama_RAG = pd.read_csv(r'F:\Super AI SS4\Level 3 - INTERN\Jupyter Notebook\Try-prompt\Abstractive\try-many-time\many-time-llama3-RAG.csv')

df_qwen = pd.read_csv(r'F:\Super AI SS4\Level 3 - INTERN\Jupyter Notebook\Try-prompt\Abstractive\try-many-time\many-time-qwen2.csv')

df_qwen_RAG = pd.read_csv(r'F:\Super AI SS4\Level 3 - INTERN\Jupyter Notebook\Try-prompt\Abstractive\try-many-time\many-time-qwen2-RAG.csv')

# %% [markdown]
# ### Gemma2

# %%
for i in range(len(df_gemma)):
    print(df_gemma.iloc[i]['summarize'])
# Out:
# ##  สรุปบทความข่าว "อีลอน มัสก์ ส่งทีมวิศวกรช่วยเหลือเด็กหมูป่า"
#
# * **หัวข้อ 1: เหตุการณ์ถ้ำหลวง-ขุนน้ำนางนอน**
#     * บทสรุป: เกิดเหตุการณ์อุบัติเหตุที่ถ้ำหลวง-ขุนน้ำนางนอน ทำให้ทีมฟุตบอลเยาวชน “หมูป่าอะคาเดมี” ประกอบด้วย 13 คน (12 นักฟุตบอลและ 1 โค้ช) ติดอยู่ภายในถ้ำ ระดับน้ำในถ้ำสูง ฝนตกต่อเนื่อง กอปรกับทางเข้าถ้ำแคบ อุปสรรคการช่วยเหลือ
#
#     * คีย์เวิร์ด: ถ้ำหลวง-ขุนน้ำนางนอน, ทีมหมูป่า, นักฟุตบอลติดถ้ำ, น้ำท่วม,
# * **หัวข้อ 2: การสนับสนุนของอีลอน มัสก์**
#     * บทสรุป: อีลอน มัสก์ ซีอีโอ SpaceX รับทราบเรื่องราว ส่งทีมวิศวกรและบริษัท Boring Co. มาสำรวจสถานการณ์และพิจารณาแนวทางช่วยเหลือ รัฐบาลไทย โดยเสนอ 3 วิธีคือ การใช้เทคโนโลยีตรวจจับใต้ดิน, Escape Pod (ห้องโดยสารเคลือบ Kevlar) และ อุโมงค์ลม
#
#     * คีย์เวิร์ด: อีลอน มัสก์, SpaceX, Boring Co., แคปซูลช่วยเหลือ, Escape Pod, อุโมงค์ลม
# * **หัวข้อ 3: ความพยายามของเจ้าหน้าที่**
# ...

# %%
for i in range(len(df_gemma_RAG)):
    print(df_gemma_RAG.iloc[i]['summarize'])
# Out:
# ## หัวข้อข่าวในบทความ
#
#
# * **1. การเสียชีวิตของ จ่าเอกสมาน กุนัน**
#
#    * บทความรายงานถึงการเสียชีวิตของจ่าเอกสมาน กุนัน ระหว่างปฏิบัติภารกิจช่วยเหลือทีมหมูป่า  อุบัติเหตุเกิดขึ้นขณะที่เขาพยายามส่งอาหารและน้ำให้กับเด็กๆ ที่ติดอยู่ในถ้ำหลวง-ขุนน้ำนางนอน
#    * รายงานกล่าวถึงการไว้อาลัยจากพระองค์เจ้า, มอบเงินเยียวยาจากธนาคารกรุงไทย และความคิดเห็นของภรรยา
#
#    * Keywords: จ่าเอกสมาน กุนัน, เสียชีวิต, ทีมหมูป่า, พระมหากรุณาธิคุณ, ธนาคารกรุงไทย
#
#
# * **2. การปฏิบัติงานช่วยเหลือทีมหมูป่า**
#
#
#    * บทความนี้รายงานเรื่องการกู้ภัยกลุ่มเด็กนักฟุตบอลและโค้ชที่ติดอยู่ในถ้ำหลวง-ขุนน้ำนอน, โดยมีการอธิบายสถานการณ์ภายในถ้ำ, อุปสรรคในการช่วยเหลือ, และการสนับสนุนจากทั้งหน่วยงานไทยและต่างประเทศ
#
#    * รวมถึงความพยายามของอีลอน มัสก์ ซีอีโอ SpaceX ที่จะส่งทีมวิศวกรมาช่วยเหลือด้วยเทคโนโลยีขุดเจาะอุโมงค์ใต้ดิน
#
#
#    * Keywords: ถ้ำหลวง, หมูป่า, กู้ภัย, อุปสรรค,  อีลอน มัสก์
#
#
#
#
# ## หัวข้อข่าวและสรุป
#
# * **1. การช่วยเหลือเด็กทีมหมูป่าอะคาเดมี**
# ...

# %% [markdown]
# ### Llama3

# %%
for i in range(len(df_llama)):
    print(df_llama.iloc[i]['summarize'])
# Out:
# **ผลการวิเคราะห์**
#
# * **ตัวเลข Topic:** 3 ตัว
# 	+ **Topic 1: การช่วยเหลือทีมหมูป่าฯ**
# 		- สรุป: ทีมหมูป่าฯ ถูกกักอยู่ในถ้ำหลวง มัสก์ เสนอแนวคิดสร้าง Escape Pod และขุดอุโมงค์ลมเพื่อช่วยเหลือผู้ประสบภัยออกมา
# 		- คำสำคัญ: หมูป่า, ถ้ำหลวง, Escape Pod, อุโมงค์ลม
# 	+ **Topic 2: การเสนองานของเอลอน มัสก์**
# 		- สรุป: เอลอน มัสก์ เสนอแนวคิดสร้าง Escape Pod และขุดอุโมงค์ลมเพื่อช่วยเหลือทีมหมูป่าฯ ใช้เทคโนโลยีตรวจจับใต้ดินและ Pod ทำด้วย Kevlar
# 		- คำสำคัญ: เอลอน มัสก์, Escape Pod, Pod, Kevlon, Teflon
# 	+ **Topic 3: สถานการณ์ในการช่วยเหลือทีมหมูป่าฯ**
# 		- สรุป: ทีมงานกำลังระดมกำลังหาทางช่วยเหลือ แต่ยังมีอุปสรรคหลายอย่าง เช่น น้ำภายในถ้ำยังสูงและมีฝนตกต่อเนื่อง
# 		- คำสำคัญ: สถานการณ์, ช่วยเหลือ, ถ้ำหลวง, อุปสรรค
# **ผลการวิเคราะห์**
#
# * **1. ความเคลื่อนไหวในการช่วยเหลือทีมหมูป่าฯ**
# 	+ สรุป: ทีมหมูป่าฯ ถูกส่งตัวไปยังถ้ำหลวง และเจ้าหน้าที่กำลังระดมกำลังหาทางช่วยเหลือ แต่ยังมีอุปสรรคสำคัญคือ ความยาวของถ้ำ และระดับน้ำภายในถ้ำยังสูง
# ...

# %%
for i in range(len(df_llama_RAG)):
    print(df_llama_RAG.iloc[i]['summarize'])
# Out:
# **ผลการวิเคราะห์**
#
# * **จำนวนหัวข้อยหลัก:** 4 หัวข้อ
#
# * **หัวข้อที่ 1: การเข้าช่วยเหลือทีมหมูป่าฯ**
# 	+ หัวข้อ: ความพยายามช่วยเหลือ
# 	+ สรุป: เอลอน มัสก์ นำเสนอแนวคิดในการช่วยเหลือทีมหมูป่าฯ โดยใช้เทคโนโลยีตรวจจับใต้ดินและ Pod หรือห้องโดยสารที่ทำด้วย Kevlar เพื่อให้ผู้ประสบภัยออกมาทางนั้นได้
# 	+ คำสำคัญ: เอลอน มัสก์, ทีมหมูป่าฯ, Pod, Kevlar
#
# * **หัวข้อที่ 2: สถานการณ์ภายในถ้ำหลวง**
# 	+ หัวข้อ: สถานการณ์ในถ้ำ
# 	+ สรุป: สถานการณ์ภายในถ้ำหลวงยังมีอุปสรรคสำคัญอย่างระดับน้ำสูงและมีฝนตกต่อเนื่อง ทำให้เจ้าหน้าที่ทุกฝ่ายกำลังระดมกำลังหาทางช่วยเหลือ
# 	+ คำสำคัญ: ถ้ำหลวง, ระดับน้ำ, ฝนตก
#
# * **หัวข้อที่ 3: การเข้าช่วยเหลือของนายอีลอน มัสก์**
# 	+ หัวข้อ: ความพยายามระดมกำลัง
# 	+ สรุป: นายอีลон มัสก์ เจ้าของบริษัท Space X และ Tesla ประกาศจะส่งทีมวิศวกร 3 คนมาช่วยสนับสนุนปฏิบัติการกู้ภัยที่ถ้ำหลวง
# 	+ คำสำคัญ: เอลอน มัสก์, ทีมวิศวกร, Space X, Tesla
#
# * **หัวข้อที่ 4: ความพยายามช่วยเหลือทีมหมูป่าฯ**
# 	+ หัวข้อ: แนวคิดในการช่วยเหลือ
# ...

# %% [markdown]
# ### Qwen2

# %%
for i in range(len(df_qwen)):
    print(df_qwen.iloc[i]['summarize'])
# Out:
# ข้อมูลที่ใช้ในการวิเคราะห์นี้เป็นภาษาไทย:
#
# 1. เทคโนโลยีและมาตรการของบริษัท Boring Co.
#
# - บริษัทด้านอวกาศสเปซเอ็กซ์และผู้ผลิตรถไฟฟ้าเทสลา, อีลอน มัสก์, เปิดเผยโครงการและเทคนิคในการช่วยเหลือการขุดเจาะใต้ดินที่ล้ำหน้าสำหรับสถานการณ์ในบ้านของไทย.
# - เขาแนะนำระบบ "Escape Pod" หรือห้องโดยสารปลอดภัยจาก Kevlar และ Teflon เพื่อช่วยเหลือเด็กๆและโคชทีมหมูป่าฯที่ถูกกักขังในถ้ำหลวง.
# - มัสก์ยังแนะนำแนวคิดสร้าง "อุโมงค์ลม" เพื่อให้กลุ่มผู้รอดชีวิตสามารถอยู่ภายในท่อแล้วได้อดเชียลงทางนั้น.
#
# 2. การสนับสนุนจากต่างประเทศ
#
# - กรมสารนิเทศของไทย, โดยผ่านสตรัดการต่างประเทศ, เคยรายงานและสรุปข้อมูลสถานการณ์ที่ถ้ำหลวงพร้อมเสนอความช่วยเหลือทางเทคนิคและความสามารถของตนเอง.
# - อีลอน มัสก์ ได้ส่งทีมวิศวกรจากสหรัฐฯ เพื่อวางแผนและการดำเนินงานในการขุดเจาะอุโมงค์ที่บ้านของไทย, และแผนการช่วยเหลือเหล่านี้กำลังถูกพิจารณา.
#
# 3. การรับผิดชอบและคำสั่งสอนจากเด็กและโคช
#
# - ตัวละครหลักของเรื่องได้สร้างภาพที่บวกให้แก่สถานการณ์น่ากังวลด้วยการส่งจดหมายแลกเปลี่ยนข้อความที่มีความหวังและความสบายใจในสถานการณ์.
# ...

# %%
for i in range(len(df_qwen_RAG)):
    print(df_qwen_RAG.iloc[i]['summarize'])
# Out:
# 1. การช่วยเหลือผู้ประสบภัยที่ถ้ำหลวง
#
# Main Topics:
# a) เทคโนโลยีจากบริษัท Boring Co. และไอเดียของ E隆 Musk
# b) แผนการช่วยเหลือและวิธีการทำงาน
# c) การส่งต่อความรู้จากน้องๆทีมหมูป่า
#
# 1. เทคโนโลยีจากบริษัท Boring Co. และไอเดียของ E隆 Musk
#     - กลุ่มทีมของ E隆 Musk มีเป้าหมายในการสร้างอุโมงค์ลมและวิทยาการขุดเจาะเพื่อช่วยเหลือผู้ประสบภัย
#     - เขาใช้เทคโนโลยี Kevlar, Teflon และหลักฐานที่ทำให้มั่นใจว่าการเข้าไปในถ้ำและการขนส่งผู้ประสบภัยจะปลอดภัย
#
# 2. แผนการช่วยเหลือและวิธีการทำงาน
#     - เกิดขึ้นจากการระดมกำลังของเจ้าหน้าที่และบริษัท Boring Co.
#     - การวางแผนในการสำรวจถ้ำ, การกำหนดทางที่ปลอดภัย และการตรวจสอบความต้องการจากผู้ประสบภัย
#
# 3. การส่งต่อความรู้จากน้องๆทีมหมูป่า
#     - ข้อเสนอแนะและการขอโทษจากเด็กทีมหมูป่า
#     - เกี่ยวกับความคิดเห็นเกี่ยวกับสถานการณ์, การขอความช่วยเหลือและความต้องการในการรับคำปรึกษา
#
# Keywords:
# - Boring Co., E隆 Musk (Elon Musk), Technology, Rescue operation, Cave exploration
# 1. การช่วยเหลือเด็กและโค้ชทีมหมูป่าจากธนาคารกรุงไทย
#
# ...
