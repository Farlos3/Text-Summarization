# %%
import pandas as pd

# %% [markdown]
# ### ThEconSum

# %% [markdown]
# #### Abstractive

# %%
df_gemma_ab = pd.read_csv(
    r'F:\AI\Super AI SS4\Level 3 - INTERN\Jupyter Notebook\Evaluate\Long-News-ThEconSum\Abstractive\gemma2-ThEconSum-Evaluate-AB.csv')
df_llama_ab = pd.read_csv(
    r'F:\AI\Super AI SS4\Level 3 - INTERN\Jupyter Notebook\Evaluate\Long-News-ThEconSum\Abstractive\llama3-ThEconSum-Evaluate-AB.csv')
df_qwen_ab = pd.read_csv(
    r'F:\AI\Super AI SS4\Level 3 - INTERN\Jupyter Notebook\Evaluate\Long-News-ThEconSum\Abstractive\qwen2-ThEconSum-Evaluate-AB.csv')

# %%
print(f'Gemma2: {df_gemma_ab.shape}\nLlama3: {df_llama_ab.shape}\nQwen2: {df_qwen_ab.shape}')
# Out:
# Gemma2: (50, 9)
# Llama3: (50, 9)
# Qwen2: (49, 9)

# %% [markdown]
# ##### Gemma2

# %%
df_gemma_ab.head(6)
# Out:
#                                           hypothesis  \
# 0  \tงานวิจัยถือเป็นขั้นตอนสำคัญที่จะบอกว่าธุรกิจ...
# 1  \tเมื่อวานนี้ MSCI ปรับลดน้ำหนักตลาดหุ้นไทย 1....
# 2  \tข้อมูลจาก UNs World Population Prospects 201...
# 3  \tนายพนม ควรสถาพร ประธานกรรมการบริหาร บริษัท เ...
# 4  \tบริษัท พีทีที โกลบอล เคมิคอล จำกัด (มหาชน) ห...
# 5  \tในยุคโควิดที่เศรษฐกิจโลกชะลอตัว ธุรกิจกลุ่มเ...
#
#                                            reference  BERT_Precision  \
# 0  \t10 บิ๊กบราเธอร์ (Big Brother) ที่พัฒนา รูปแบ...        0.825808
# 1  \tวานนี้ MSCI ปรับลดน้ำหนักตลาดหุ้นไทย 1.05 หม...        0.781536
# 2  \tข้อมูลของ UNs World Population Prospects 201...        0.839029
# 3  \tAGE ยอดขายถ่านหินไตรมาสแรกพุ่งขึ้นเกือบเท่าต...        0.821049
# 4  \tนายทิติพงษ์ จุลพรศิริดี ผู้จัดการฝ่ายหน่วยงา...        0.857326
# 5  คงกระพัน อินทรแจ้ง ประธานเจ้าหน้าที่ บริหาร บร...        0.786303
#
#    BERT_Recall   BERT_F1   ROUGE-1   ROUGE-2   ROUGE-L  ROUGE_Score
# ...

# %%
avg_gemma_ab = df_gemma_ab.select_dtypes(include='number').mean()
avg_gemma_ab
# Out:
# BERT_Precision    0.818673
# BERT_Recall       0.816428
# BERT_F1           0.817487
# ROUGE-1           0.635784
# ROUGE-2           0.400735
# ROUGE-L           0.580107
# ROUGE_Score       0.538875
# dtype: float64

# %% [markdown]
# ##### Llama3

# %%
df_llama_ab.head(6)
# Out:
#                                           hypothesis  \
# 0            10 บิ๊กบราเธอร์ ที่พัฒนา รูปแบบธุรกิ...
# 1            เมื่อวานนี้ MSCI ได้ปรับลดล้ำหนักตลา...
# 2            จากข้อมูลของ UNs World Population Pr...
# 3            ทันหุ้น-AGE ยอดขายถ่านหินไตรมาสแรกพุ...
# 4            ทันหุ้น - PTTGC ลุ้นรับรู้กำไรทันที ...
# 5            ณัฐณิชา ดอนสุวรรณ กรุงเทพธุรกิจ ธุรก...
#
#                                            reference  BERT_Precision  \
# 0  \t10 บิ๊กบราเธอร์ (Big Brother) ที่พัฒนา รูปแบ...        0.924537
# 1  \tวานนี้ MSCI ปรับลดน้ำหนักตลาดหุ้นไทย 1.05 หม...        0.783934
# 2  \tข้อมูลของ UNs World Population Prospects 201...        0.790502
# 3  \tAGE ยอดขายถ่านหินไตรมาสแรกพุ่งขึ้นเกือบเท่าต...        0.777822
# 4  \tนายทิติพงษ์ จุลพรศิริดี ผู้จัดการฝ่ายหน่วยงา...        0.779957
# 5  คงกระพัน อินทรแจ้ง ประธานเจ้าหน้าที่ บริหาร บร...        0.772256
#
#    BERT_Recall   BERT_F1   ROUGE-1   ROUGE-2   ROUGE-L  ROUGE_Score
# ...

# %%
avg_llama_ab = df_llama_ab.select_dtypes(include='number').mean()
avg_llama_ab
# Out:
# BERT_Precision    0.797874
# BERT_Recall       0.796602
# BERT_F1           0.797157
# ROUGE-1           0.622739
# ROUGE-2           0.415446
# ROUGE-L           0.573546
# ROUGE_Score       0.537244
# dtype: float64

# %% [markdown]
# ##### Qwen2

# %%
df_qwen_ab.head(6)
# Out:
#                                           hypothesis  \
# 0          เริ่มต้นด้วยการพัฒนาธุรกิจเพื่อสังคมที...
# 1  ทั้งหมดเป็นความรู้สึกต่อการเขียนหุ้นที่ไม่ได้ม...
# 2  ทั่วโลก มีคนจำนวน 36 ล้านคนที่ต้องเผชิญกับปัญห...
# 3  ที่ผ่านมา, บริษัทได้ลงทุนสู่ผลิตภัณฑ์ที่มีมูลค...
# 4  ที่วันที่ 22 มกราคม พ.ศ. 2564 PTTGC เข้าสู่กระ...
# 5  ที่ผ่านมา ชานนท์จิตตชโลธร ผู้บริหารสถานีบริการ...
#
#                                            reference  BERT_Precision  \
# 0  \t10 บิ๊กบราเธอร์ (Big Brother) ที่พัฒนา รูปแบ...        0.725177
# 1  \tวานนี้ MSCI ปรับลดน้ำหนักตลาดหุ้นไทย 1.05 หม...        0.726704
# 2  \tข้อมูลของ UNs World Population Prospects 201...        0.720746
# 3  \tนายทิติพงษ์ จุลพรศิริดี ผู้จัดการฝ่ายหน่วยงา...        0.776243
# 4  คงกระพัน อินทรแจ้ง ประธานเจ้าหน้าที่ บริหาร บร...        0.743761
# 5  กระทรวงเกษตรและสหกรณ์ ร่วมกับ บริษัท ปตท. จำกั...        0.763173
#
#    BERT_Recall   BERT_F1   ROUGE-1   ROUGE-2   ROUGE-L  ROUGE_Score
# ...

# %%
avg_qwen_ab = df_qwen_ab.select_dtypes(include='number').mean()
avg_qwen_ab
# Out:
# BERT_Precision    0.755832
# BERT_Recall       0.754997
# BERT_F1           0.755359
# ROUGE-1           0.487592
# ROUGE-2           0.220487
# ROUGE-L           0.415945
# ROUGE_Score       0.374675
# dtype: float64

# %% [markdown]
# #### Extractive

# %%
df_gemma_ex = pd.read_csv(
    r'F:\AI\Super AI SS4\Level 3 - INTERN\Jupyter Notebook\Evaluate\Long-News-ThEconSum\Extractive\gemma2-ThEconSum-Evaluate-EX.csv')
df_llama_ex = pd.read_csv(
    r'F:\AI\Super AI SS4\Level 3 - INTERN\Jupyter Notebook\Evaluate\Long-News-ThEconSum\Extractive\llama3-ThEconSum-Evaluate-EX.csv')
df_qwen_ex = pd.read_csv(
    r'F:\AI\Super AI SS4\Level 3 - INTERN\Jupyter Notebook\Evaluate\Long-News-ThEconSum\Extractive\qwen2-ThEconSum-Evaluate-EX.csv')

# %%
print(f'Gemma2: {df_gemma_ex.shape}\nLlama3: {df_llama_ex.shape}\nQwen2: {df_qwen_ex.shape}')
# Out:
# Gemma2: (50, 9)
# Llama3: (50, 9)
# Qwen2: (49, 9)

# %% [markdown]
# ##### Gemma2

# %%
df_gemma_ex.head(6)
# Out:
#                                           hypothesis  \
# 0  \tนายอนุสรณ์ แสงนิ่มนวล อดีตกรรมการผู้จัดการให...
# 1  \tทันทีที่เรียนจบปริญญาตรีวิศวกรรมเคมี ที่มหาว...
# 2  บริษัท พีทีที โกลบอล เคมิคอล จำกัด (มหาชน) หรื...
# 3  \tนายจักรพงส์ สุเมธโชติเมธา ประธาน เจ้าหน้าที่...
# 4  \tนายชาญศิลป์ ตรีนุชกร ประธานเจ้าหน้าที่บริหาร...
# 5  \tขาโจ๋ปากซอย เริ่มต้นกับ SME D Bank จัดหนักเส...
#
#                                            reference  BERT_Precision  \
# 0  นายอนุสรณ์ แสงนิ่มนวล กล่าวว่า การตั้งบรรษัทพล...        0.807995
# 1    \tทันทีที่เรียนจบปริญญาตรีวิศวกรรมเคมี ที่มห...        0.934671
# 2  \t บริษัท พีทีที โกลบอล เคมิคอล จำกัด หรือ GC ...        0.869404
# 3           นายจักรพงส์ สุเมธโชติเมธา ประธานเจ้าห...        0.826899
# 4  นายชาญศิลป์ ตรีนุชกร ประธานเจ้าหน้าที่บริหารแล...        0.863537
# 5           SME D Bank สินเชื่อถูกสุดในระบบ 0.08%...        0.793792
#
#    BERT_Recall   BERT_F1   ROUGE-1   ROUGE-2   ROUGE-L  ROUGE_Score
# ...

# %%
avg_gemma_ex = df_gemma_ex.select_dtypes(include='number').mean()
avg_gemma_ex
# Out:
# BERT_Precision    0.841365
# BERT_Recall       0.839486
# BERT_F1           0.840367
# ROUGE-1           0.693513
# ROUGE-2           0.513326
# ROUGE-L           0.676770
# ROUGE_Score       0.627870
# dtype: float64

# %% [markdown]
# ##### Llama3

# %%
df_llama_ex.head(6)
# Out:
#                                           hypothesis  \
# 0            นายอนุสรณ์ แสงนิ่มนวล อดีตกรรมการผู้...
# 1            ทันทีที่เรียนจบปริญญาตรีวิศวกรรมเคมี...
# 2            บริษัท พีทีที โกลบอล เคมิคอล จำกัด (...
# 3            ทันหุ้น - SKE ซุ่มดีลร่วมทุนโรงไฟฟ้า...
# 4            ปั้นพื้นที่กว่า 3 พันไร่อีอีซีไอ รับ...
# 5            เริ่มต้นกับ SME D Bank จัดหนักเสิร์ฟ...
#
#                                            reference  BERT_Precision  \
# 0  นายอนุสรณ์ แสงนิ่มนวล กล่าวว่า การตั้งบรรษัทพล...        0.814033
# 1    \tทันทีที่เรียนจบปริญญาตรีวิศวกรรมเคมี ที่มห...        0.833215
# 2  \t บริษัท พีทีที โกลบอล เคมิคอล จำกัด หรือ GC ...        0.870065
# 3           นายจักรพงส์ สุเมธโชติเมธา ประธานเจ้าห...        0.745019
# 4  นายชาญศิลป์ ตรีนุชกร ประธานเจ้าหน้าที่บริหารแล...        0.822310
# 5           SME D Bank สินเชื่อถูกสุดในระบบ 0.08%...        0.819348
#
#    BERT_Recall   BERT_F1   ROUGE-1   ROUGE-2   ROUGE-L  ROUGE_Score
# ...

# %%
avg_llama_ex = df_llama_ex.select_dtypes(include='number').mean()
avg_llama_ex
# Out:
# BERT_Precision    0.819609
# BERT_Recall       0.813765
# BERT_F1           0.816330
# ROUGE-1           0.637908
# ROUGE-2           0.454370
# ROUGE-L           0.612012
# ROUGE_Score       0.568097
# dtype: float64

# %% [markdown]
# ##### Qwen2

# %%
df_qwen_ex.head(6)
# Out:
#                                           hypothesis  \
# 0          นายนุสรณ์แสงนิ่มนวล อดีตกรรมการผู้จัดก...
# 1          บริษัท พีทีที โกลบอล เคมิคอล และบริษัท...
# 2  ทันหุ้น - SKE ซุ่มดีลร่วมกับผู้ซื้อที่ดินในจัง...
# 3  ปั้นพื้นที่กว่า 3 พันไร่อีอีซีไอ รับนักลงทุนไท...
# 4  ส่วนของนายถวนันท์ ธเนศเดชสุนทร ผู้บริหารดี เวล...
# 5  สแกน อินเตอร์ หรือ SCN และปตท. ลงนามในสัญญาซื้...
#
#                                            reference  BERT_Precision  \
# 0  นายอนุสรณ์ แสงนิ่มนวล กล่าวว่า การตั้งบรรษัทพล...        0.740492
# 1  \t บริษัท พีทีที โกลบอล เคมิคอล จำกัด หรือ GC ...        0.800636
# 2           นายจักรพงส์ สุเมธโชติเมธา ประธานเจ้าห...        0.756907
# 3  นายชาญศิลป์ ตรีนุชกร ประธานเจ้าหน้าที่บริหารแล...        0.765291
# 4           SME D Bank สินเชื่อถูกสุดในระบบ 0.08%...        0.703047
# 5            ดร.ฤทธี กิจพิพิธ กรรมการผู้จัดการใหญ...        0.785405
#
#    BERT_Recall   BERT_F1   ROUGE-1   ROUGE-2   ROUGE-L  ROUGE_Score
# ...

# %%
avg_qwen_ex = df_qwen_ex.select_dtypes(include='number').mean()
avg_qwen_ex
# Out:
# BERT_Precision    0.776884
# BERT_Recall       0.767867
# BERT_F1           0.772292
# ROUGE-1           0.531382
# ROUGE-2           0.289666
# ROUGE-L           0.473444
# ROUGE_Score       0.431497
# dtype: float64

# %%
data = {
    'avg_gemma_ab': avg_gemma_ab,
    'avg_llama_ab': avg_llama_ab,
    'avg_qwen_ab': avg_qwen_ab
}

comparison_df = pd.DataFrame(data, index=['BERT_Precision', 'BERT_Recall', 'BERT_F1', 'ROUGE-1', 'ROUGE-2', 'ROUGE-L', 'ROUGE_Score'])
comparison_df
# Out:
#                 avg_gemma_ab  avg_llama_ab  avg_qwen_ab
# BERT_Precision      0.818673      0.797874     0.755832
# BERT_Recall         0.816428      0.796602     0.754997
# BERT_F1             0.817487      0.797157     0.755359
# ROUGE-1             0.635784      0.622739     0.487592
# ROUGE-2             0.400735      0.415446     0.220487
# ROUGE-L             0.580107      0.573546     0.415945
# ROUGE_Score         0.538875      0.537244     0.374675

# %%
data = {
    'avg_gemma_ab': avg_gemma_ex,
    'avg_llama_ab': avg_llama_ex,
    'avg_qwen_ab': avg_qwen_ex
}

comparison_df = pd.DataFrame(data, index=['BERT_Precision', 'BERT_Recall', 'BERT_F1', 'ROUGE-1', 'ROUGE-2', 'ROUGE-L', 'ROUGE_Score'])
comparison_df
# Out:
#                 avg_gemma_ab  avg_llama_ab  avg_qwen_ab
# BERT_Precision      0.841365      0.819609     0.776884
# BERT_Recall         0.839486      0.813765     0.767867
# BERT_F1             0.840367      0.816330     0.772292
# ROUGE-1             0.693513      0.637908     0.531382
# ROUGE-2             0.513326      0.454370     0.289666
# ROUGE-L             0.676770      0.612012     0.473444
# ROUGE_Score         0.627870      0.568097     0.431497
