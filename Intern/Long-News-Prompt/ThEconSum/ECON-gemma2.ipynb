# %% [markdown]
# ### Ollama

# %%
# !ollama list
# Out:
# NAME                   	ID          	SIZE  	MODIFIED
# nomic-embed-text:latest	0a109f422b47	274 MB	7 days ago
# llama3:8b              	365c0bd3c000	4.7 GB	13 days ago
# llama3.1:8b            	75382d0899df	4.7 GB	2 weeks ago
# llama3:text            	870a5d02cfaf	4.7 GB	2 weeks ago
# qwen2:7b               	e0d4e1163c58	4.4 GB	2 weeks ago
# gemma2:9b              	ff02c3702f32	5.4 GB	2 weeks ago
# mistral:latest         	2ae6f6dd7a3d	4.1 GB	8 weeks ago

# %%
from langchain_community.chat_models import ChatOllama
from langchain.prompts import ChatPromptTemplate, SystemMessagePromptTemplate, HumanMessagePromptTemplate

# %%
local_model = "gemma2:9b"
llm = ChatOllama(model=local_model)

# %%
llm
# Out:
# ChatOllama(model='gemma2:9b')

# %% [markdown]
# ### ThEconSum

# %%
import pandas as pd

df = pd.read_json(
    r'F:\AI\Super AI SS4\Level 3 - INTERN\Dataset\THEconSum\AIFORTHAI-TextSummarizationCorpus\Text-Summarization-Corpus.json')

df.shape
# Out:
# (3189, 5)

# %%
df.head(4)
# Out:
#                                              content  \
# 0            สมเด็จพระกนิษฐาธิราชเจ้า กรมสมเด็จพร...
# 1            สดุดีพระบิดาพลังงานไทย          พระม...
# 2            สำนักงานสภาพัฒนาการเศรษฐกิจและสังคมแ...
# 3            กรุงเทพวันอาทิตย์          ปอรนุช วร...
#
#                                           extractive  \
# 0  \tสมเด็จพระกนิษฐาธิราชเจ้า กรมสมเด็จพระเทพรัตน...
# 1  \t พระบาทสมเด็จพระปรมินทรมหาภูมิพลอดุลยเดช ทรง...
# 2  \tสำนักงานสภาพัฒนาการเศรษฐกิจและสังคมแห่งชาติ ...
# 3   \tสมเด็จพระเจ้าลูกเธอ เจ้าฟ้าพัชรกิติยาภา นเร...
#
#                                          abstractive  \
# 0  \tสมเด็จพระกนิษฐาธิราชเจ้า กรมสมเด็จพระเทพรัตน...
# 1  \t พระบาทสมเด็จพระปรมินทรมหาภูมิพลอดุลยเดช ทรง...
# 2  \tสำนักงานสภาพัฒนาการเศรษฐกิจและสังคมแห่งชาติ ...
# 3  \tสมเด็จพระเจ้าลูกเธอ เจ้าฟ้าพัชรกิติยาภา นเรน...
#
#                          author                         datePublish
# 0  ผู้จัดการสุดสัปดาห์ 360 องศา     ฉบับวันที่ 19 ธันวาคม พ.ศ. 2563
# 1               ประชาชาติธุรกิจ      ฉบับวันที่ 23 ตุลาคม พ.ศ. 2560
# 2                 กรุงเทพธุรกิจ    ฉบับวันที่ 27 มิถุนายน พ.ศ. 2562
# 3                 กรุงเทพธุรกิจ  ฉบับวันที่ 16 กุมภาพันธ์ พ.ศ. 2563

# %%
columns = df.columns
print(columns)
# Out:
# Index(['content', 'extractive', 'abstractive', 'author', 'datePublish'], dtype='object')

# %%
print(f"Content: \n{df.iloc[0]['content']}\n\n\n extractive: \n{df.iloc[0]['extractive']}\n\n abstractive: \n{df.iloc[0]['abstractive']}")
# Out:
# Content:
#           สมเด็จพระกนิษฐาธิราชเจ้า กรมสมเด็จพระเทพรัตนราชสุดาฯ สยามบรมราชกุมารี เสด็จพระราชดำเนินทอดพระเนตรความก้าวหน้าโครงการจัดตั้ง ศูนย์เรียนรู้เกษตรนวัต สถาบันเทคโนโลยีจิตรลดา และทรงเป็นประธานในพิธีลงนามบันทึกข้อตกลงความร่วมมือระหว่าง 3 หน่วยงาน เพื่อสนับสนุนการดำเนินงานของศูนย์ฯ ส่งเสริมและต่อยอดศักยภาพด้านการศึกษาและวิจัยในการพัฒนานวัตกรรมด้านการเกษตร          เชื่อแน่ว่า หลายคนต้องเคยได้ยินชื่อหรือรู้จัก ศูนย์เรียนรู้เกษตรนวัต สถาบันเทคโนโลยีจิตรลดา ซึ่งตั้งอยู่บนพื้นที่ 145 ไร่ ของ ต.ป่ายุบใน อ.วังจันทร์ จ.ระยอง โดยพื้นที่ตรงนี้ บริษัท ปตท. จำกัด (มหาชน) ได้ทูลเกล้าถวายสมเด็จพระกนิษฐาธิราชเจ้า กรมสมเด็จพระเทพรัตนราชสุดาฯ สยามบรมราชกุมารี เมื่อวันที่ 5 สิงหาคม 2558          ต่อมาในปี 2561 กรมสมเด็จพระเทพรัตนราชสุดาฯ ได้ทรงมีพระราชดำริที่จะสร้างพื้นที่ดังกล่าวให้เป็นศูนย์เรียนรู้ เพื่อเผยแพร่ความรู้ด้านเกษตรสมัยใหม่ ให้แก่นักเรียนและผู้สนใจทั่วไป และเกิดเป็น ศูนย์เรียนรู้เกษตรนวัต สถาบันเทคโนโลยีจิตรลดา อย่างที่เห็นเช่นปัจจุบันโดยตั้งแต่ปี 2561 จนถึงปัจจุบัน ปตท. พร้อมด้วยหน่วยงานต่าง ๆ ได้ให้ความร่วมมือในการดำเนินโครงการเพื่อให้เป็นไปตามผังแม่บทที่กำหนดไว้ และมีความคืบหน้าไปแล้วหลายส่วน ได้แก่          1. งานก่อสร้างอาคารและสาธารณูปโภค โดยการก่อสร้างอาคารอยู่ระหว่างดำเนินงานด้านสถาปัตยกรรม ทดสอบระบบ และงานขุดบ่อน้ำบ่อที่ 2 ขนาด 9.63 ไร่ ซึ่งคาดว่าการก่อสร้างทั้งหมดจะแล้วเสร็จภายในเดือนมกราคม 2564          2. งานพัฒนาพื้นที่ป่านิเวศ จำนวน 20.45 ไร่ ซึ่งมีคณะวนศาสตร์ มหาวิทยาลัยเกษตรศาสตร์ ให้คำแนะนำในการคัดเลือกชนิดไม้และให้คำปรึกษาด้านวิชาการ โดยป่านิเวศนี้ใช้กล้าไม้ป่า 3 ระดับ จำนวน 79 ชนิด ใช้กล้าไม้กว่า 20,000 ต้นปลูกตามทฤษฎีแบบมิยาวากิ ซึ่งปัจจุบันได้ดำเนินการปลูกครบหมดแล้ว          3. การพัฒนาพื้นที่แปลงไม้ผล จำนวน 40 ไร่ ซึ่งดำเนินการปลูกไปแล้ว 35 ไร่ ของพื
ังหวัดระยอง นายไพรินทร์ ชูโชติถาวร นายกสภาสถาบันวิทยสิริเมธี นายอรรถพล ฤกษ์พิบูลย์ ประธานเจ้าหน้าที่บริหารและกรรมการผู้จัดการใหญ่ บริษัท ปตท. จำกัด (มหาชน) พร้อมด้วยข้าราชการ ผู้บริหาร พนักงานกลุ่ม ปตท. เฝ้าทูลละอองพระบาทเฝ้ารับเสด็จ และถวายรายงานความก้าวหน้าของโครงการฯ          หลังจากนั้น กรมสมเด็จพระเทพฯ ทรงเป็นประธานในพิธีลงนามบันทึกข้อตกลงความร่วมมือระหว่าง สถาบันเทคโนโลยีจิตรลดา บริษัท สยามคูโบต้าคอร์ปอเรชั่น จำกัด และบริษัท ปตท. จำกัด  (มหาชน) โดยมี รศ.ดร.คุณหญิงสุมณฑา พรหมบุญ อธิการบดีสถาบันเทคโนโลยีจิตรลดา นายทาคาโนบุ อะซึมะ กรรมการ ...
#
#
#  extractive:
# 	สมเด็จพระกนิษฐาธิราชเจ้า กรมสมเด็จพระเทพรัตนราชสุดาฯ สยามบรมราชกุมารี เสด็จพระราชดำเนินทอดพระเนตรความก้าวหน้าโครงการจัดตั้ง ศูนย์เรียนรู้เกษตรนวัต สถาบันเทคโนโลยีจิตรลดา และทรงเป็นประธานในพิธีลงนามบันทึกข้อตกลงความร่วมมือระหว่าง 3 หน่วยงาน เพื่อสนับสนุนการดำเนินงานของศูนย์ฯ
# 	ศูนย์เรียนรู้เกษตรนวัต สถาบันเทคโนโลยีจิตรลดา ต.ป่ายุบใน อ.วังจันทร์ จ.ระยอง โดยพื้นที่ตรงนี้ บริษัท ปตท. จำกัด (มหาชน) ได้ทูลเกล้าถวายกรมสมเด็จพระเทพฯ เมื่อวันที่ 5 สิงหาคม 2558 ต่อมาในปี 2561 กรมสมเด็จพระเทพฯ ได้ทรงมีพระราชดำริที่จะสร้างพื้นที่ดังกล่าวให้เป็นศูนย์เรียนรู้ เพื่อเผยแพร่ความรู้ด้านเกษตรสมัยใหม่ ให้แก่นักเรียนและผู้สนใจทั่วไป และเกิดเป็นศูนย์เรียนรู้เกษตรนวัต สถาบันเทคโนโลยีจิตรลดา หน่วยงานต่าง ๆ ได้ให้ความร่วมมือในการดำเนินโครงการเพื่อให้เป็นไปตามผังแม่บทที่กำหนดไว้ และมีความคืบหน้าไปแล้วหลายส่วน ได้แก่
# 	1. งานก่อสร้างอาคารและสาธารณูปโภค คาดว่าการก่อสร้างทั้งหมดจะแล้วเสร็จภายในเดือนมกราคม 2564
# 	2. งานพัฒนาพื้นที่ป่านิเวศ จำนวน 20.45 ไร่ ซึ่งมีคณะวนศาสตร์ มหาวิทยาลัยเกษตรศาสตร์ ให้คำแนะนำในการคัดเลือกชนิดไม้และให้คำปรึกษาด้านวิชาการ
# 	3. การพัฒนาพื้นที่แปลงไม้ผล จำนวน 40 ไร่ ซึ่งดำเนินการปลูกไปแล้ว 35 ไร่
# 	นอกจากนี้ ปตท. ยังได้ร่วมกับสำนักงานพัฒนาวิทยาศาสตร์และเทคโนโลยีแห่งชาติ (สวทช.) สนับสนุนการทำเกษตรที่นำเทคโนโลยีเข้ามาช่วยในระบบการผลิต พร้อมสนับสนุนการเรียนการสอนสาขาวิชาเกษตรนวัต โรงเรียนจิตรลดาวิชาชีพ สถาบันเทคโนโลยีจิตรลดา
# 	ทั้งนี้ เมื่อวันที่ 4 พฤศจิกายน ที่ผ่านมา สมเด็จพระกนิษฐาธิราชเจ้า กรมสมเด็จพระเทพรัตนราชสุดาฯ สยามบรมราชกุมารี ได้เสด็จพระราชดำเนินทอดพระเนตรความก้าวหน้าของโครงการฯ หลังจากนั้นทรงเป็นประธานในพิธีลงนามบันทึกข้อตกลงความร่วมมือระหว่าง สถาบันเทคโนโลยีจิตรลดา บริษัท สยามคูโบต้าคอร์ปอเรชั่น จำกัด และบริษัท ปตท. จำกัด  (มหาชน) แก่นสารของบันทึกดังกล่าวนั้น มีวัตถุประสงค์เพื่อสนับสนุนการดำเนินงานศูนย์เรียนรู้เกษตรนวัต สถาบันเทคโนโลยีจิตรลดา มีเป้าหมายในการส่งเสริมและต่อยอดศักยภาพในด้านการศึกษาและวิจัยร่วมกันในการพัฒนานวัตกรรมทางด้านการเกษตร นอกจากนั้นยังนับเป็นจุดเริ่มต้นในการแลกเปลี่ยนข้อมูลข่าวสารและองค์ความรู้ร่วมกันระหว่าง 3 หน่วยงาน ในด้านนวัตกรรมทางการเกษตรสมัยใหม่ ที่จะเป็นประโยชน์ต่อเกษตรกรและชุมชน
#
#
#  abstractive:
# 	สมเด็จพระกนิษฐาธิราชเจ้า กรมสมเด็จพระเทพรัตนราชสุดาฯ สยามบรมราชกุมารี เสด็จพระราชดำเนินทอดพระเนตรความก้าวหน้าโครงการจัดตั้ง ศูนย์เรียนรู้เกษตรนวัต สถาบันเทคโนโลยีจิตรลดา และทรงเป็นประธานในพิธีลงนามบันทึกข้อตกลงความร่วมมือระหว่าง 3 หน่วยงาน เพื่อสนับสนุนการดำเนินงานของศูนย์ฯ
# 	ศูนย์เรียนรู้เกษตรนวัต สถาบันเทคโนโลยีจิตรลดา ตั้งอยู่ใน ต.ป่ายุบใน อ.วังจันทร์ จ.ระยอง พื้นที่ตรงนี้ บริษัท ปตท. จำกัด (มหาชน) ได้ทูลเกล้าถวาย กรมสมเด็จพระเทพฯ เมื่อวันที่ 5 สิงหาคม 2558 ต่อมาในปี 2561 กรมสมเด็จพระเทพฯ ได้ทรงมีพระราชดำริที่จะสร้างพื้นที่ดังกล่าวให้เป็นศูนย์เรียนรู้ เพื่อเผยแพร่ความรู้ด้านเกษตรสมัยใหม่ ให้แก่นักเรียนและผู้สนใจทั่วไป จึงเกิดเป็นศูนย์เรียนรู้เกษตรนวัต สถาบันเทคโนโลยีจิตรลดา หน่วยงานต่าง ๆ ได้ให้ความร่วมมือในการดำเนินโครงการเพื่อให้เป็นไปตามผังแม่บทที่กำหนดไว้ และมีความคืบหน้าไปแล้วหลายส่วน ได้แก่
# 	1. งานก่อสร้างอาคารและสาธารณูปโภค คาดว่าการก่อสร้างทั้งหมดจะแล้วเสร็จภายในเดือนมกราคม 2564
# 	2. งานพัฒนาพื้นที่ป่านิเวศ จำนวน 20.45 ไร่ โดยมีคณะวนศาสตร์ มหาวิทยาลัยเกษตรศาสตร์ ให้คำแนะนำในการคัดเลือกชนิดไม้และให้คำปรึกษาด้านวิชาการ
# 	3. การพัฒนาพื้นที่แปลงไม้ผล จำนวน 40 ไร่ ดำเนินการปลูกไปแล้ว 35 ไร่
# 	นอกจากนี้ ปตท. ยังได้ร่วมกับสำนักงานพัฒนาวิทยาศาสตร์และเทคโนโลยีแห่งชาติ (สวทช.) สนับสนุนการทำเกษตรที่นำเทคโนโลยีเข้ามาช่วยในระบบการผลิต อีกทั้งยังสนับสนุนการเรียนการสอนสาขาวิชาเกษตรนวัต โรงเรียนจิตรลดาวิชาชีพ สถาบันเทคโนโลยีจิตรลดา
# 	ทั้งนี้ วันที่ 4 พฤศจิกายน ที่ผ่านมา สมเด็จพระกนิษฐาธิราชเจ้า กรมสมเด็จพระเทพรัตนราชสุดาฯ สยามบรมราชกุมารี ได้เสด็จพระราชดำเนินทอดพระเนตรความก้าวหน้าของโครงการฯ หลังจากนั้นทรงเป็นประธานในพิธีลงนามบันทึกข้อตกลงความร่วมมือระหว่าง สถาบันเทคโนโลยีจิตรลดา บริษัท สยามคูโบต้าคอร์ปอเรชั่น จำกัด และบริษัท ปตท. จำกัด  (มหาชน) แก่นสารของบันทึกมีวัตถุประสงค์เพื่อสนับสนุนการดำเนินงานของศูนย์เรียนรู้เกษตรนวัต สถาบันเทคโนโลยีจิตรลดา โดยมีเป้าหมายเพื่อส่งเสริมและต่อยอดศักยภาพในด้านการศึกษาและวิจัยร่วมกันในการพัฒนานวัตกรรมทางด้านการเกษตร นอกจากนั้นยังนับเป็นจุดเริ่มต้นในการแลกเปลี่ยนข้อมูลข่าวสารและองค์ความรู้ในด้านนวัตกรรมทางการเกษตรสมัยใหม่ร่วมกันระหว่าง 3 หน่วยงาน ที่จะเป็นประโยชน์ต่อเกษตรกรและชุมชน

# %%
text = df.iloc[1]['content']
print(text)
# Out:
#           สดุดีพระบิดาพลังงานไทย          พระมหากรุณาธิคุณ พระบาทสมเด็จพระปรมินทรมหาภูมิพลอดุลยเดช ทรงพระราชทานแผ่ไพศาล ถึงปวงพสกนิกรทุกหมู่เหล่า ด้วยพระอัจฉริยภาพ และพระวิริยอุตสาหะ ทรงวิจัย-ค้นคว้าทางเลือกใหม่ ๆ ในทุกสรรพวิชา เป็นเครื่องมือในการพัฒนาเศรษฐกิจอย่างยั่งยืน 1 ในนั้นคือ ข้อค้นพบเรื่องพลังงานทางเลือก-พลังงานทดแทน อันเป็นพลังสำคัญในการสนับสนุนการเติบโตทางเศรษฐกิจ ควบคู่การอนุรักษ์พลังงานและสิ่งแวดล้อมอย่างสมดุล-มั่นคงในระยะ
พียงอย่างเดียว มาสู่การทำความเข้าใจว่าชุมชนและสังคมที่ ปตท.เข้าไปทำธุรกิจด้วย ต้องมีการแลกเปลี่ยนซึ่งกันและกัน ซึ่งท้ายที่สุดธุรกิจก็จะเติบโตไปพร้อมกับความเข้มแข็งของสังคม          แหล่งพลังงานที่เป็นฐานผลิตหลักของ ปตท. ทั้งแหล่งปิโตรเลียม โครงการบงกช และอาทิตย์ อยู่ในสายพระเนตรอันยาวไกลของในหลวงรัชกาลที่ 9 ทรงพระกรุณาโปรดเกล้าโปรดกระหม่อม พระราชทานชื่อ สำหรับพื้นที่ทั้ง 2 แหล่งปิโตรเลียมว่า พื้นที่ปิโตรเลียมนวมินทร์          กิจการพัฒนาพลังงาน ได้รับพระมหากรุณาธิคุณจากพระองค์ เช่น การลงทุนสร้างโรงแยกก๊าซธรรมชาติ จังหวัดระยอง เพื่อนำทรัพยากรของชาติขึ้นมาใช้ให้เกิดประโยชน์สูงสุด เมื่อพระองค์ได้เสด็จพระราชดำเนินมาในพิธีเปิดโรงแยกก๊าซ เคยทรงรับสั่งว่า ประเทศเรายังยากจนอยู่ ดังนั้น ควรใช้ผลผลิตในประเทศให้เกิดประโยชน์ต่อประชาชนในประเทศให้เต็มที่มากที่สุด จากวันนั้นเป็นต้นมา โรงแยกก๊าซดังกล่าว ได้ทำหน้าที่รองรับความต้องการใช้พลังงาน ทั้งก๊าซปิโตรเลียมเหลว (LPG) ก๊าซอีเทนสำหรับใช้เป็นวัตถุดิบสำหรับอุตสาหกรรมปิโตรเคมี          หญ้าแฝกในแบรนด์ ภัทรพัฒน์          พระวิสัยทัศน์อันยาวไกลของในหลวงรัชกาลที่ 9 เรื่อง หญ้าแฝก ถูกน้อมนำมาเป็น พืชนวัตกรรม ป้องกันการชะล้างพังทลายในพื้นที่ลาดชัน ในพื้นที่ อ.ทองผาภูมิ จ.กาญจนบุรี และต่อยอดพัฒนาผลิตภัณฑ์จากใบหญ้าแฝก สร้างโอกาสในการเสริมรายได้และพัฒนาเป็นวิสาหกิจชุมชน และส่งเป็นสินค้าจำหน่ายภายใต้ตราสินค้า ภัทรพัฒน์ ของมูลนิธิชัยพัฒนา          พระองค์ยังได้พระราชทานหญ้าแฝก จากโครงการพัฒนาและส่งเสริมการปลูกและรณรงค์การใช้หญ้าแฝก อันเนื่องมาจากพระราชดำริ ซึ่ง ปตท.มาต่อยอด ด้วยการนำหญ้าแฝกมาปลูกครั้งแรกในพื้นที่โครงการท่อส่งก๊าซธรรมชาติไทย-เมียนมา และเนื่องในโอกาสที่ทรงเจริญพระชนมพรรษา 80 พรรษา ปตท.ร่วมกับเครือข่าย ปลูกและฟี้นฟูผืนป่าทั่วประเทศให้ได้ 1 ล้านไร่          เทวินทร์ บอกว่า วิถีชีวิตที่พอเพียงและการปลูกป่า ปตท.น้อมนำมาพัฒนาเป็น สวนป่าสมุนไพร ควบคู่โครงการ รักษ์น้ำ รักษ์ป่า รักษ ...

# %%
# 	เทวินทร์ บอกว่า วิถีชีวิตที่พอเพียงและการปลูกป่า ปตท.น้อมนำมาพัฒนาเป็นสวนป่าสมุนไพรควบคู่กับโครงการ รักษ์น้ำ รักษ์ป่า รักษ์คุ้งบางกระเจ้า จนถึงวันนี้ได้ดำเนินการพลิกฟื้นทั้งสิ่งแวดล้อมและเศรษฐกิจชุมชน ให้สามารถดำเนินชีวิตตามหลักปรัชญาเศรษฐกิจพอเพียง ควบคู่กับการพัฒนาการท่องเที่ยวเชิงนิเวศอย่างยั่งยืน

# %% [markdown]
# ### LLM Generate

# %% [markdown]
# #### Abstractive

# %%
def summarize_abstractive(text, llm):
    prompt = f"""Write a summary in a narrative style that presents the content in a continuous, flowing manner, focusing on a chronological order of events. The narrative should be smooth without abrupt breaks, covering all relevant points comprehensively, but without delving into deep, specific details. The content should provide a clear overview of the entire event or story to give readers a broad understanding.
    Please read the following news article carefully and follow the instructions below

    {text}

    Instructions:
    - Write each paragraph based on the sequence of events or background, focusing on a continuous storytelling approach.
    - Use \t at the beginning of each paragraph to create indentation.
    - DO NOT leave blank lines between paragraphs. All paragraphs must be continuous with no blank lines.
    - There is NO need to give titles for each paragraph. Focus on telling the story while covering key points.

    IMPORTANT: All your answers must be in Thai. Ensure that the Thai translation accurately conveys the meaning and context of the original content."""

    system_template = f"""You are an expert summarizer with the ability to distill complex information into concise and accurate summaries. Your summaries are clear, coherent, and excellent at identifying key points while preserving the essence of the original text."""

    system_message_prompt = SystemMessagePromptTemplate.from_template(system_template)
    human_message_prompt = HumanMessagePromptTemplate.from_template(prompt)

    chat_prompt = ChatPromptTemplate.from_messages([system_message_prompt, human_message_prompt])
    messages = chat_prompt.format_messages(text=text)

    response = llm(messages)
    return response.content

# %%
summarized_text = summarize_abstractive(text, llm)
summarized_text

# %%
print(summarized_text)
# Out:
#           แหล่งปิโตรเลียมว่า พื้นที่ปิโตรเลียมนวมินทร์ กิจการพัฒนาพลังงาน ได้รับพระมหากรุณาธิคุณจากพระองค์ เช่น การลงทุนสร้างโรงแยกก๊าซธรรมชาติ จังหวัดระยอง เพื่อนำทรัพยากรของชาติขึ้นมาใช้ให้เกิดประโยชน์สูงสุด เมื่อพระองค์ได้เสด็จพระราชดำเนินมาในพิธีเปิดโรงแยกก๊าซ เคยทรงรับสั่งว่า ประเทศเรายังยากจนอยู่ ดังนั้น ควรใช้ผลผลิตในประเทศให้เกิดประโยชน์ต่อประชาชนในประเทศให้เต็มที่มากที่สุด จากวันนั้นเป็นต้นมา โรงแยกก๊าซดังกล่าว ได้ทำหน้าที่รองรับความต้องการใช้พลังงาน ทั้งก๊าซปิโตรเลียมเหลว (LPG) ก๊าซอีเทนสำหรับใช้เป็นวัตถุดิบสำหรับอุตสาหกรรมปิโตรเคมี
#           พระวิสัยทัศน์อันยาวไกลของในหลวงรัชกาลที่ 9 เรื่อง หญ้าแฝก ถูกน้อมนำมาเป็น พืชนวัตกรรม ป้องกันการชะล้างพังทลายในพื้นที่ลาดชัน ในพื้นที่ อ.ทองผาภูมิ จ.กาญจนบุรี และต่อยอดพัฒนาผลิตภัณฑ์จากใบหญ้าแฝก สร้างโอกาสในการเสริมรายได้และพัฒนาเป็นวิสาหกิจชุมชน และส่งเป็นสินค้าจำหน่ายภายใต้ตราสินค้า ภัทรพัฒน์ ของมูลนิธิชัยพัฒนา
#           พระองค์ยังได้พระราชทานหญ้าแฝก จากโครงการพัฒนาและส่งเสริมการปลูกและรณรงค์การใช้หญ้าแฝก อันเนื่องมาจากพระราชดำริ ซึ่ง ปตท.มาต่อยอด ด้วยการนำหญ้าแฝกมาปลูกครั้งแรกในพื้นที่โครงการท่อส่งก๊าซธรรมชาติไทย-เมียนมา และเนื่องในโอกาสที่ทรงเจริญพระชนมพรรษา 80 พรรษา ปตท.ร่วมกับเครือข่าย ปลูกและฟี้นฟูผืนป่าทั่วประเทศให้ได้ 1 ล้านไร่
#           เทวินทร์ บอกว่า วิถีชีวิตที่พอเพียงและการปลูกป่า ปตท.น้อมนำมาพัฒนาเป็น สวนป่าสมุนไพร ควบคู่โครงการ รักษ์น้ำ รักษ์ป่า รักษ์คุ้งบางกระเจ้า ก็เกิดขึ้นจากพระราชดำริของพระองค์ ในระหว่างที่ทรงประทับเฮลิคอปเตอร์พระที่นั่ง ผ่านคุ้งบางกระเจ้า ในปี 2530 ทรงมีพระราชดำริว่า สมควรสงวนพื้นที่แห่งนี้ไว้เป็นพื้นที่สีเขียวของกรุงเทพฯและปริมณทล เนื่องจากลมมรสุมจากอ่าวไทยจะพัดเอาอากาศบริสุทธิ์เข้ามาไล่อากาศเสียในกรุงเทพฯ เป็นเวลากว่าปีละ 9 เดือน
#           จนถึงวันนี้โครงการดังกล่าว ปตท.ได้ดำเนินการในการเพิ่มพื้นที่สีเขียว และคงความอุดมสมบูรณ์ พลิกฟี้นทั้งสิ่งแวดล้อมและเศรษฐกิจชุมชนคุ้งบางกระเจ้า ให้สามารถดำเนินชีวิตตามหลักปรัชญาเศรษฐกิจพอเพียง ควบคู่กับการพัฒนาการท่องเที่ยวเชิงนิเวศอย่างยั่งยืน

# %% [markdown]
# #### Extractive

# %%
def summarize_extractive(text, llm):
    prompt = f"""Create a summary by selecting and combining key sentences directly from the original text. The summary should present the content in a chronological order, covering all relevant points comprehensively, but without adding any new words or phrases not present in the original text. The extracted sentences should provide a clear overview of the entire event or story to give readers a broad understanding.
    Please read the following news article carefully and follow the instructions below:

    {text}

    Instructions:
    - Use \t at the beginning of each paragraph to create indentation.
    - DO NOT leave blank lines between paragraphs. All paragraphs must be continuous with no blank lines.
    - DO NOT add any new words or phrases. Use ONLY the exact text from the original article.
    - There is NO need to give titles for each paragraph. Focus on presenting the key information while maintaining the original wording.
    - Please DO NOT generate anything else, generate ONLY the summary.

    IMPORTANT: Ensure that you only extract and combine existing sentences from the Thai text. Do not translate or rephrase any content."""

    system_template = f"""You are an expert in extractive summarization with the ability to identify and select the most important sentences from complex texts. Your summaries are coherent compilations of original sentences that accurately represent the key points and overall narrative of the source material."""

    system_message_prompt = SystemMessagePromptTemplate.from_template(system_template)
    human_message_prompt = HumanMessagePromptTemplate.from_template(prompt)

    chat_prompt = ChatPromptTemplate.from_messages([system_message_prompt, human_message_prompt])
    messages = chat_prompt.format_messages(text=text)

    response = llm(messages)
    return response.content

# %%
text_ex = df.iloc[2]['content']
print(text_ex)
# Out:
#           สำนักงานสภาพัฒนาการเศรษฐกิจและสังคมแห่งชาติ (สศช.) อยู่ระหว่างการปรับโครงสร้างองค์กรให้มีความ ทันสมัยสอดคล้องกับบริบทเศรษฐกิจและสังคมที่เปลี่ยนแปลงไปจากอดีต รวมทั้งรองรับภารกิจที่เพิ่มขึ้นทั้งในแง่ของการกำกับติดตามยุทธศาสตร์ชาติและแผนปฏิรูป ขณะเดียวกันก็ยังคงต้องทำหน้าที่เรื่องการเสนอแนะแนวนโยบายที่จำเป็นสำหรับการพัฒนาเศรษฐกิจสังคมของประเทศในอนาคต          กรุงเทพธุรกิจ ภารกิจหน้าที่ที่เพิ่มขึ้น ของดังกล่าวทำให้คณะกรรมการสภาพัฒนาการเศรษฐกิจและสังคมแห่งชาติ หรือ บอร์ดสภาพัฒน์ ชุดใหม่จะมี บทบาทในการชี้ทิศทางการวางแผน ผลักดันและขับเคลื่อนงานของ สศช. โดยคณะกรรมการชุดใหม่มีกำหนดการ จะประชุมนัดแรกในวันที่ 3 ก.ค.นี้ เพื่อกำหนดกรอบและเป้าหมายการทำงานร่วมกัน          ล่าสุดมีประกาศสำนักนายกรัฐมนตรี เรื่อง แต่งตั้งประธานสภาพัฒนาการเศรษฐกิจและสังคมแห่งชาติ และกรรมการสภาผู้ทรงคุณวุฒิ 12 ราย แบ่งเป็นผู้ที่เคยเป็น คณะกรรมการมาแล้ว 8 คน คือ 1.นายสนิท อักษรแก้ว เป็นประธานกรรมการสภาพัฒน์ 2.คุณหญิงกษมา วรวรรณ ณ อยุธยา อดีตปลัดกระทรวงศึกษาธิการ 3.นายคณิศ แสงสุพรรณ เลขาธิการ คณะกรรมการนโยบายเขตพัฒนาพิเศษภาคตะวันออก (สกพอ.)          4.นายทวีศักดิ์ กออนันตกูล อดีตผู้อำนวยการสำนักงานพัฒนา วิทยาศาสตร์และเทคโนโลยีแห่งชาติ 5.นายนินนาท ไชยธีรภิญโญ ประธานคณะกรรมการ บริษัท โตโยต้า มอเตอร์ ประเทศไทย จำกัด          6.นายวรากรณ์ สามโกเศศ อธิการบดีกิตติคุณมหาวิทยาลัย ธุรกิจบัณฑิตย์ 7.นายศักรินทร์ ภูมิรัตน อดีตอธิการบดีมหาวิทยาลัยเทคโนโลยีพระจอมเกล้าธนบุรี 8.นางเสาวณีย์ ไทยรุ่งโรจน์ อธิการบดีมหาวิทยาลัยหอการค้าไทย          ส่วนผู้ที่เข้ามาเป็นกรรมการครั้งแรก มี 4 คน คือ 1.นายเทวินทร์ วงศ์วานิช อดีตประธานเจ้าหน้าที่บริหารและกรรมการผู
สำหรับเหตุผลสำคัญที่ต้องการให้คนรุ่นใหม่เข้ามาทำงานในกรรมการ สศช.มากขึ้น เพราะต้องการให้เกิดการทำงานที่ผสมผสานกันระหว่างคนรุ่นใหม่ที่มีความรู้ กับคนรุ่นเก่าที่มีประสบการณ์ ซึ่งจะเป็นประโยชน์ต่อการมองทิศทางการพัฒนาประเทศในอนาคต          สำหรับอำนาจหน้าที่ของสภาพัฒนา การเศรษฐกิจและสังคมแห่งชาติ ได้แก่ 1.กำหนดกรอบทิศทางการพัฒนาเศรษฐกิจและสังคมของประเทศสอดคล้องกับยุทธศาสตร์ชาติ และสภาพการณ์ทางเศรษฐกิจและสังคมทั้งของประเทศและของโลก 2.จัดทำร่างแผนพัฒนาเศรษฐกิจและสังคมแห่งชาติ          3.เสนอแนะ ให้คำปรึกษา และให้ความเห็นเกี่ยวกับการขับเคลื่อนการพัฒนาเศรษฐกิจและสังคมตามแผนพัฒนาฯ รวมทั้งการแก้ไขเพิ่มเติมหรือปรับปรุงกฎหมาย กฎ หรือระเบียบที่ส่งผลต่อการพัฒนาในด้านต่างๆ ต่อนายกรัฐมนตรี หรือคณะรัฐมน ...

# %%
summarized_text = summarize_extractive(text_ex, llm)
summarized_text

# %%
print(summarized_text)

# %% [markdown]
# ### Evaluate

# %% [markdown]
# #### BERT Score

# %%
from bert_score import score

# %%
def bert_score(candidate, reference):
    P, R, F1 = score([candidate], [reference], lang='th', verbose=False)

    precision = float(P[0])
    recall = float(R[0])
    f1 = float(F1[0])

    print(f"BERT Score Metrics:")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1 Score: {f1:.4f}")

# %%
def calculate_bert_score(candidate, reference):
    P, R, F1 = score([candidate], [reference], lang='th', verbose=False)
    bert_score = {
        'precision': float(P[0]),
        'recall': float(R[0]),
        'f1': float(F1[0])
    }
    return bert_score

# %% [markdown]
# #### ROUGE Score

# %%
from pythainlp.tokenize import word_tokenize
from rouge import Rouge

# %%
def rouge_score(hypothesis, reference):
    hypothesis_tokenized = ' '.join(word_tokenize(hypothesis))
    reference_tokenized = ' '.join(word_tokenize(reference))

    rouge = Rouge()
    scores = rouge.get_scores(hypothesis_tokenized, reference_tokenized)[0]

    rouge_types = ['rouge-1', 'rouge-2', 'rouge-l']
    rouge_labels = ['ROUGE-1', 'ROUGE-2', 'ROUGE-L']

    for rouge_type, label in zip(rouge_types, rouge_labels):
        print(f"\n{label}:")
        print(f"  Precision: {scores[rouge_type]['p']:.5f}")
        print(f"  Recall: {scores[rouge_type]['r']:.5f}")
        print(f"  F1-score: {scores[rouge_type]['f']:.5f}")

# %%
def calculate_rouge_score(candidate, reference):
    hypothesis_tokenized = ' '.join(word_tokenize(candidate))
    reference_tokenized = ' '.join(word_tokenize(reference))

    rouge = Rouge()
    scores = rouge.get_scores(hypothesis_tokenized, reference_tokenized)[0]

    rouge_score = {
        'rouge-1': {
            'precision': scores['rouge-1']['p'],
            'recall': scores['rouge-1']['r'],
            'f1': scores['rouge-1']['f']
        },
        'rouge-2': {
            'precision': scores['rouge-2']['p'],
            'recall': scores['rouge-2']['r'],
            'f1': scores['rouge-2']['f']
        },
        'rouge-l': {
            'precision': scores['rouge-l']['p'],
            'recall': scores['rouge-l']['r'],
            'f1': scores['rouge-l']['f']
        }
    }
    return rouge_score

# %% [markdown]
# #### Loop for Evaluate

# %%
from tqdm import tqdm
import random

# %% [markdown]
# ##### Abstractive

# %%
summarized_texts = []
references = []

random_sampled_texts = df[['content', 'abstractive']].sample(n=50, random_state=42).reset_index(drop=True)

for index, row in tqdm(random_sampled_texts.iterrows(), desc="Summarizing 50 Random ...", total=50):
    summarized_text = summarize_abstractive(row['content'], llm)
    summarized_texts.append(summarized_text)
    
    references.append(row['abstractive'])

df_sum = pd.DataFrame({
    'hypothesis': summarized_texts,
    'reference': references
})
# Out:
# Summarizing 50 Random ...: 100%|██████████| 50/50 [5:05:18<00:00, 366.38s/it]

# %%
bert_precisions = []
bert_recalls = []
bert_f1_scores = []

for index, row in tqdm(df_sum.iterrows(), total=df_sum.shape[0], desc="BERT Scores ..."):
    candidate = row['hypothesis']
    reference = row['reference']

    bert_score = calculate_bert_score(candidate, reference)

    bert_precisions.append(bert_score['precision'])
    bert_recalls.append(bert_score['recall'])
    bert_f1_scores.append(bert_score['f1'])

df_sum['BERT_Precision'] = bert_precisions
df_sum['BERT_Recall'] = bert_recalls
df_sum['BERT_F1'] = bert_f1_scores
# Out:
# BERT Scores ...:   0%|          | 0/50 [00:00<?, ?it/s]C:\Users\Nitro 5\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\models\bert\modeling_bert.py:439: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at ..\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:263.)
#   attn_output = torch.nn.functional.scaled_dot_product_attention(
# BERT Scores ...: 100%|██████████| 50/50 [01:20<00:00,  1.60s/it]

# %%
rouge1_scores = []
rouge2_scores = []
rougel_scores = []
rouge_avg_scores = []

for index, row in df_sum.iterrows():
    candidate = row['hypothesis']
    reference = row['reference']

    rouge_score = calculate_rouge_score(candidate, reference)

    rouge1_f1 = rouge_score['rouge-1']['f1']
    rouge2_f1 = rouge_score['rouge-2']['f1']
    rougel_f1 = rouge_score['rouge-l']['f1']

    rouge1_scores.append(rouge1_f1)
    rouge2_scores.append(rouge2_f1)
    rougel_scores.append(rougel_f1)

    avg_rouge_score = (rouge1_f1 + rouge2_f1 + rougel_f1) / 3
    rouge_avg_scores.append(avg_rouge_score)

df_sum['ROUGE-1'] = rouge1_scores
df_sum['ROUGE-2'] = rouge2_scores
df_sum['ROUGE-L'] = rougel_scores
df_sum['ROUGE_Score'] = rouge_avg_scores

# %%
df_sum.head(5)
# Out:
#                                           hypothesis  \
# 0  \tงานวิจัยถือเป็นขั้นตอนสำคัญที่จะบอกว่าธุรกิจ...
# 1  \tเมื่อวานนี้ MSCI ปรับลดน้ำหนักตลาดหุ้นไทย 1....
# 2  \tข้อมูลจาก UNs World Population Prospects 201...
# 3  \tนายพนม ควรสถาพร ประธานกรรมการบริหาร บริษัท เ...
# 4  \tบริษัท พีทีที โกลบอล เคมิคอล จำกัด (มหาชน) ห...
#
#                                            reference  BERT_Precision  \
# 0  \t10 บิ๊กบราเธอร์ (Big Brother) ที่พัฒนา รูปแบ...        0.825808
# 1  \tวานนี้ MSCI ปรับลดน้ำหนักตลาดหุ้นไทย 1.05 หม...        0.781536
# 2  \tข้อมูลของ UNs World Population Prospects 201...        0.839029
# 3  \tAGE ยอดขายถ่านหินไตรมาสแรกพุ่งขึ้นเกือบเท่าต...        0.821049
# 4  \tนายทิติพงษ์ จุลพรศิริดี ผู้จัดการฝ่ายหน่วยงา...        0.857326
#
#    BERT_Recall   BERT_F1   ROUGE-1   ROUGE-2   ROUGE-L  ROUGE_Score
# 0     0.805484  0.815519  0.533030  0.266867  0.482916     0.427604
# 1     0.785328  0.783427  0.633147  0.394702  0.607076     0.544975
# 2     0.851351  0.845145  0.647826  0.464238  0.621739     0.577934
# 3     0.805083  0.812988  0.626959  0.330579  0.570533     0.509357
# 4     0.856087  0.856706  0.732095  0.604575  0.673740     0.670137

# %%
print(df_sum.iloc[1]['hypothesis'])
# Out:
# 	เมื่อวานนี้ MSCI ปรับลดน้ำหนักตลาดหุ้นไทย 1.05 หมื่นล้านบาท ทำให้ดัชนีปิดตลาดแดนบวกได้ 14.38 จุด มาที่ 1,582.96 จุด และมูลค่าการซื้อขายสุดอลังการกว่า 175,296 แสนล้านบาท สะท้อนว่า ตลาดหุ้นไทยแข็งแกร่ง.  แนวรับที่เคยหวั่น ๆ กันว่า จะหลุด 1,530-1,500 จุด นั้น ตอนนี้มองข้ามไปได้เลย.
#
# 	ประเด็นบวกสำคัญคือ แผนการฉีดวัคซีนที่แม้ว่าจะออกมาแบบมั่ว ๆ ไปตามสถานการณ์ แต่ล่าสุด เหมือนจะคลำปัญหา หาหนทางเจอ คือเร่งฉีดบุคคลในพื้นที่เสี่ยง เช่น กรุงเทพฯ และปริมณฑล ให้เร็วที่สุด ก็น่าจะช่วยลดยอดผู้ติดเชื้อได้ พร้อมกับเปิดเมืองได้เร็วขึ้นด้วย เพราะอย่าลืมว่า กรุงเทพฯ ก็คือประเทศไทย หากกรุงเทพฯ รอด ประเทศไทยก็รอด!!
#
# 	ด้านบัตรกรุงไทย หรือ KTC มีบิ๊กล็อตกว่า 110 ล้านหุ้น บริษัท ถูกเทขายอย่างหนัก ทำให้ราคาหุ้นปรับตัวลง. รายงานข่าวระบุว่า แนวโน้ม Q2/64 กระเป๋ายังตุงแน่นอน ฟันธง!!
#
# 	หุ้น OR “หุ้นมหาชน” ก่อนหน้านี้เซอร์ไพรส์เข้าคำนวณดัชนีฟุตซี่ ล่าสุดต่อสัญญากับ เซเว่นฯ ไปอีก ราคาหุ้น 30.00 บาท ที่เป็นแนวต้าน ตอนนี้ น่าจะพลิกกลับมาเป็นแนวรับ สัญญาณทางเทคนิค กำลังบอกว่า ราคาเริ่มกลับหัวขึ้น ประกอบกับรายใหญ่เข้าเก็บของแถว ๆ 28.00-29.00 บาท เรียบร้อยแล้ว น่าจะได้เวลาเป็นขาขึ้น หลังเข้าตลาดมาแล้วเกือบ 4 เดือน
#
# 	HPT บมจ.โฮม พอตเทอรี่ ของกลุ่ม “เชาว์กิตติโสภณ” แย้มข่าวดีมาตลอดว่าไตรมาส 2 มีออเดอร์จากต่างชาติเข้ามาเยอะ ทำให้มี Backlog มากกว่า 60 ล้านบาท สูงสุดเป็นประวัติการณ์ ขณะที่ผู้ถือ HPT-W1 สามารถแจ้งสิทธิแปลงสภาพครั้งสุดท้าย ถึงวันที่ 3 มิถุนายนนี้ ราคาแปรสภาพเบา ๆ 0.49589 ต่อหุ้น ถือว่ายังมีเก็บให้ลงทุนได้ เพราะราคาหุ้นแม่อยู่แถว 1 บาท ยังไงก็อย่าลืมใช้สิทธิกัน ส่วนเงินที่ได้การแปลงสภาพเห็นว่าจะนำไปใช้หมุนเวียนในกิจการ และขยายช่องทางการตลาดในอนาคต
#
# 	ประสิทธิ์ บุญดวงประเสริฐ ประธานคณะผู้บริหาร บมจ. เจริญโภคภัณฑ์อาหาร CPF รับข่าวดี 2 เด้ง ผลประกอบการไตรมาส 1/64 ออกมาโตต่อเนื่องในช่วงวิกฤต และยังได้รับรางวัลสูงสุดด้านการดูแลพนักงานปลอดภัย เคารพหลักสิทธิมนุษชน Asias Best Workplace Report จากเวทีประกวดรายงานด้านความยั่งยืนแห่งเอเชีย Asia Sustainability Report Awards (ASRA) 2020 ที่สิงคโปร์ ก่อนหน้านี้ยังเป็นอันดับ 1 ของบริษัทไทยใน องค์กรนายจ้างยอดเยี่ยมระดับโลก ปี 2020 ที่จัดลำดับโดยนิตยสารฟอร์บส์ จากการดูแลพนักงานปลอดภัยจากโควิด-19 ได้โดดเด่น การันตี องค์กรยืนหนึ่งองค์กรต้นแบบด้านสิทธิมนุษยชน

# %%
print(df_sum.iloc[1]['reference'])
# Out:
# 	วานนี้ MSCI ปรับลดน้ำหนักตลาดหุ้นไทย 1.05 หมื่นล้านบาท แต่ดัชนีกลับปิดแดนบวกได้ 14.38 จุด มาที่ 1,582.96 จุด มูลค่าซื้อขายกว่า 175,296 แสนล้านบาท สะท้อนความแกร่งของตลาดหุ้น ซึ่งมีแผนการฉีดวัคซีนเป็นประเด็นบวกสำคัญ
#          บัตรกรุงไทย คือ KTC มีบิ๊กล็อตกว่า 110 ล้านหุ้น เฉลี่ยหุ้นละ 74.75 บาท ต่ำกว่าราคาปิดวันที่ 25 พ.ค. กว่า 7-8% ทำให้รายย่อยค้างยอดดอย ส่วนกลุ่มมอร์แกน สแตนเลย์ ที่ถือหุ้นมา 3 เดือนกว่าๆ ทำกำไรไปกว่าพันล้านบาท
#           แบงก์กสิกรไทย KBANK ประกาศย้ายสำนักงานใหญ่จากราษฎร์บูรณะไปที่พหลโยธินตามเดิม แต่เป็นการย้ายแค่ชื่อ โดยเชื่อว่าเป็นเรื่องของ “ฮวงจุ้ย” ส่วนราคาหุ้น KBANK วานนี้ปิดลบ 2.50 บาท ไปที่ 121.50 บาท เปลี่ยนแปลง -2.02% มูลค่าซื้อขายกว่า 21,129 ล้านบาท
#           หุ้นกลุ่มเจมาร์ท JMART JMT และ SINGER ปรับลงต่อเนื่องเพราะมีอัพไซด์จำกัด ซึ่ง JMART ยังมีแนวต้านสำคัญ 40.00 บาท แต่แนวโน้ม Q2/64 น่าจะออกมาดี
#           หลังเข้าตลาดเกือบ 4 เดือนและการต่อสัญญากับเซเว่นฯ ทำให้ราคาหุ้น ของ บมจ.ปตท. น้ำมันและการค้าปลีก หรือ OR อยู่ที่ 30.00 บาทซึ่งเป็นแนวต้าน อีกทั้งรายใหญ่เข้าซื้อแถวๆ 28.00-29.00 บาท ทำให้ตอนนี้กำลังพลิกกลับมาเป็นแนวรับ
#           HPT บมจ.โฮม พอตเทอรี่ ของกลุ่ม “เชาว์กิตติโสภณ” มีออเดอร์จากต่างชาติในไตรมาส 2  ทำให้มี Backlog มากกว่า 60 ล้านบาท ขณะที่ผู้ถือ HPT-W1 สามารถแจ้งสิทธิแปลงสภาพครั้งสุดท้าย ถึงวันที่ 3 มิถุนายน ราคา 0.49589 ต่อหุ้น
#           ประสิทธิ์ บุญดวงประเสริฐ ประธานคณะผู้บริหาร บมจ. เจริญโภคภัณฑ์อาหาร CPF รับผลประกอบการไตรมาส 1/64 เติบโตและยังได้รับรางวัลสูงสุดด้านการดูแลพนักงานปลอดภัย เคารพหลักสิทธิมนุษชน Asias Best Workplace Report จากเวทีประกวดรายงานด้านความยั่งยืนแห่งเอเชีย Asia Sustainability Report Awards (ASRA) 2020 ที่สิงคโปร์อีกด้วย

# %%
df_sum.to_csv(
    r'F:\AI\Super AI SS4\Level 3 - INTERN\Jupyter Notebook\Evaluate\Long-News-ThEconSum\Abstractive\gemma2-ThEconSum-Evaluate.csv', index=False)

# %%
averages = {}

for col in df_sum.columns:
    if col not in ['hypothesis', 'reference']:
        averages[col] = df_sum[col].mean()

for col, avg in averages.items():
    print(f"Average {col}: {avg:.6f}")
# Out:
# Average BERT_Precision: 0.818673
# Average BERT_Recall: 0.816428
# Average BERT_F1: 0.817487
# Average ROUGE-1: 0.635784
# Average ROUGE-2: 0.400735
# Average ROUGE-L: 0.580107
# Average ROUGE_Score: 0.538875

# %% [markdown]
# ##### Extractive

# %%
summarized_ex = []
reference = []

random_sampled_texts = df[['content', 'extractive']].sample(n=50, random_state=21).reset_index(drop=True)

for index, row in tqdm(random_sampled_texts.iterrows(), desc="Summarizing 50 Random ...", total=50):
    summarized_text = summarize_extractive(row['content'], llm)
    summarized_ex.append(summarized_text)
    
    reference.append(row['extractive'])

df_sum_ex = pd.DataFrame({
    'hypothesis': summarized_ex,
    'reference': reference
})
# Out:
# Summarizing 50 Random ...: 100%|██████████| 50/50 [5:44:31<00:00, 413.44s/it]

# %%
df_sum_ex.to_csv(
    r'F:\AI\Super AI SS4\Level 3 - INTERN\Jupyter Notebook\Evaluate\Long-News-ThEconSum\Extractive\gemma2-ThEconSum-Evaluate-EX-1.csv', index=False)

# %%
bert_precisions = []
bert_recalls = []
bert_f1_scores = []

for index, row in tqdm(df_sum_ex.iterrows(), total=df_sum_ex.shape[0], desc="BERT Scores ..."):
    candidate = row['hypothesis']
    reference = row['reference']

    bert_score = calculate_bert_score(candidate, reference)

    bert_precisions.append(bert_score['precision'])
    bert_recalls.append(bert_score['recall'])
    bert_f1_scores.append(bert_score['f1'])

df_sum_ex['BERT_Precision'] = bert_precisions
df_sum_ex['BERT_Recall'] = bert_recalls
df_sum_ex['BERT_F1'] = bert_f1_scores
# Out:
# BERT Scores ...: 100%|██████████| 50/50 [01:08<00:00,  1.36s/it]

# %%
rouge1_scores = []
rouge2_scores = []
rougel_scores = []
rouge_avg_scores = []

for index, row in df_sum_ex.iterrows():
    candidate = row['hypothesis']
    reference = row['reference']

    rouge_score = calculate_rouge_score(candidate, reference)

    rouge1_f1 = rouge_score['rouge-1']['f1']
    rouge2_f1 = rouge_score['rouge-2']['f1']
    rougel_f1 = rouge_score['rouge-l']['f1']

    rouge1_scores.append(rouge1_f1)
    rouge2_scores.append(rouge2_f1)
    rougel_scores.append(rougel_f1)

    avg_rouge_score = (rouge1_f1 + rouge2_f1 + rougel_f1) / 3
    rouge_avg_scores.append(avg_rouge_score)

df_sum_ex['ROUGE-1'] = rouge1_scores
df_sum_ex['ROUGE-2'] = rouge2_scores
df_sum_ex['ROUGE-L'] = rougel_scores
df_sum_ex['ROUGE_Score'] = rouge_avg_scores

# %%
df_sum_ex
# Out:
#                                            hypothesis  \
# 0   \tนายอนุสรณ์ แสงนิ่มนวล อดีตกรรมการผู้จัดการให...
# 1   \tทันทีที่เรียนจบปริญญาตรีวิศวกรรมเคมี ที่มหาว...
# 2   บริษัท พีทีที โกลบอล เคมิคอล จำกัด (มหาชน) หรื...
# 3   \tนายจักรพงส์ สุเมธโชติเมธา ประธาน เจ้าหน้าที่...
# 4   \tนายชาญศิลป์ ตรีนุชกร ประธานเจ้าหน้าที่บริหาร...
# 5   \tขาโจ๋ปากซอย เริ่มต้นกับ SME D Bank จัดหนักเส...
# 6   \tสแกน อินเตอร์ หรือ SCN เซ็นสัญญาซื้อขายก๊าซธ...
# 7   \tปตท.สผ.ประกาศตัดสินใจ ลงทุนขั้นสุดท้าย โครงก...
# 8   \tบริษัทหลักทรัพย์ เอเซีย พลัส จำกัด (มหาชน) ร...
# 9   \tเปิดทุนใหญ่กว่า 23 ราย ภาครัฐเร่งลงทุนในอุตส...
# 10  \tดร.ทวารัฐ สูตะบุตร ผู้อำนวยการสำนักงานนโยบาย...
# 11  นายเกรียงชัย บุญโพธิอภิชาติ ประธานเจ้าหน้าที่ฝ...
# 12  \tผู้สื่อข่าว มิติหุ้น รายงานว่า บมจ.ทีอาร์ซี ...
# 13  \tพงษ์พันธุ์ เล่าลือกันมานานร่วม 10 ปี จนถึงวั...
# 14  \tนายเติมชัย บุนนาค ประธานเจ้าหน้าที่บริหารและ...
# 15  \tหลอดพลาสติก ที่คนทั่วไปอาจมองไม่เห็นคุณค่า เ...
# 16  \tทิพยประกันภัย ส่งประกันภัยไซเบอร์ส่วนบุคคล ค...
# 17  \tภาวะตลาดหุ้นไทยเข้าใกล้ช่วงวันหยุดยาวต่อเนื่...
# 18  \tบริษัทหลักทรัพย์ ซีจีเอส-ซีไอเอ็มบี (ประเทศไ...
# 19  \tทันหุ้น- PTTEP เข้าข่ายหุ้นเด่น หลังราคาน้ำม...
# 20  กำพล อังศุเกษตร์แทบสำลักน้ำที่เพิ่งดื่มหลังจาก...
# 21  \tนายธวัชชัย จักรไพศาล รอง ผู้ว่าการเชื้อเพลิง...
# 22  \tนายกีรพัฒน์ เจียมเศรษฐ ผู้ช่วยผู้ว่าการการไฟ...
# 23  \tการรักษาความมั่นคงปลอดภัย เพื่อให้มั่นใจว่าใ...
# 24  บริษัทแม่คาลเท็กซ์ ประกาศทวงส่วนแบ่งการตลาดน้ำ...
# 25  \tทันหุ้น - SKE เผยศึกษาลงทุนโรงไฟฟ้าชุมชน และ...
# 26  \tนายอุตตม สาวนายน รัฐมนตรีว่าการกระทรวงอุตสาห...
# 27  \tผู้สื่อข่าว ประชาชาติธุรกิจ รายงานว่า ในวันท...
# 28  \tณ สิ้นเดือน พ.ค. 2564 ดัชนี (SET Index) ปิดท...
# 29  \tบิ๊กยานยนต์ สแควร์ กรุ๊ป ปลื้มภาพรวมตลาดรถไท...
# 30  \tเมื่อวันที่ 11 กุมภาพันธ์ 2564 บมจ.ปตท. น้ำม...
# 31  \tนายสนธิรัตน์ สนธิจิรวงศ์ รัฐมนตรีว่าการกระทร...
# 32  \tทันหุ้น - PTTEP ได้ฤกษ์เริ่มการผลิตก๊าซธรรมช...
# 33  \tจับตา บมจ.ปตท. น้ำมันและการค้าปลีก (OR) ติด ...
# 34  บริษัทหลักทรัพย์ ฟิลลิป (ประเทศไทย) จำกัด (มหา...
# 35  \tหลังผลการเลือกตั้ง ประธานาธิบดีสหรัฐมีความชั...
# 36  \tผู้สื่อข่าว มิติหุ้น รายงานว่า บมจ. โกลบอลกร...
# 37  \tนางภรณี ทองเย็น รองกรรมการผู้อำนวยการ สายงาน...
# 38  \tบมจ.ปตท. น้ำมันและการค้าปลีก หรือ OR ราคาหุ้...
# 39  \tอานิสงส์ราคาน้ำมันเพิ่มสูงขึ้นต่อเนื่องบวกกั...
# 40  \tกระบี่เดียวดาย ท่ามกลางฝุ่นตลบของการตั้งครม....
# 41  \tดร.ศิริ จิระพงษ์พันธ์ รัฐมนตรีว่าการกระทรวงพ...
# 42  \tแม้ว่าปลาซุกิจะมีคุณค่าทางโภชนาการและมีศักยภ...
# 43  นายภูมินทร์ หะริณสุต ประธานสมาคมเจ้าของเรือไทย...
# 44  \tเปิดศักราช 2559 ราคาน้ำมันโลกร่วงผล็อย เบรนท...
# 45  \tทันหุ้น - PTTEP โชว์งบ Q2/2560 วันนี้ (27 ก....
# 46  \tนางสาวกัญญา ติลกเรืองชัย กรรมการผู้จัดการ บร...
# 47  \tมติคณะกรรมการนโยบายเขตพัฒนาพิเศษภาคตะวันออก ...
# 48  \tนายสนธิรัตน์ สนธิจิรวงศ์ รมว.พลังงาน ลงพื้นท...
# 49  \tนายอุตสาหกรรมได้แก้ปัญหากรณีโรงงานในเขตเศรษฐ...
#
#                                             reference  BERT_Precision  \
# 0   นายอนุสรณ์ แสงนิ่มนวล กล่าวว่า การตั้งบรรษัทพล...        0.807995
# 1     \tทันทีที่เรียนจบปริญญาตรีวิศวกรรมเคมี ที่มห...        0.934671
# 2   \t บริษัท พีทีที โกลบอล เคมิคอล จำกัด หรือ GC ...        0.869404
# 3            นายจักรพงส์ สุเมธโชติเมธา ประธานเจ้าห...        0.826899
# 4   นายชาญศิลป์ ตรีนุชกร ประธานเจ้าหน้าที่บริหารแล...        0.863537
# 5            SME D Bank สินเชื่อถูกสุดในระบบ 0.08%...        0.793792
# 6             ดร.ฤทธี กิจพิพิธ กรรมการผู้จัดการใหญ...        0.854265
# 7             นายพงศธร ทวีสิน ประธานเจ้าหน้าที่บริ...        0.852827
# 8             บริษัทหลักทรัพย์ เอเซีย พลัส จำกัด  ...        0.833885
# 9   \tร่างมาตรการพัฒนาอุตสาหกรรมชีวภาพของไทย ในมือ...        0.841119
# 10  \tดร.ทวารัฐ สูตะบุตร ผู้อำนวยการสำนักงานนโยบาย...        0.821097
# 11  นายเกรียงชัย บุญโพธิอภิชาติ ประธานเจ้าหน้าที่ฝ...        0.888674
# 12  \t  บมจ.ทีอาร์ซี คอนสตรัคชั่น หรือ TRC โดยนายภ...        0.880650
# 13            เล่าลือกันมานานว่า หน่วยงานราชการที่...        0.813439
# 14            นายเติมชัย บุนนาค ประธานเจ้าหน้าที่บ...        0.870888
# 15  \t  หลอดพลาสติก ที่คนทั่วไปอาจมองไม่เห็นคุณค่า...        0.872264
# 16  \tดร.สมพร สืบถวิลกุล กรรมการผู้จัดการใหญ่ บริษ...        0.832951
# 17  ภาวะตลาดหุ้นไทยเข้าใกล้ช่วงวันหยุดยาวช่วงเทศกา...        0.909012
# 18            บริษัทหลักทรัพย์ ซีจีเอส-ซีไอเอ็มบี ...        0.896486
# 19  \t บริษัทหลักทรัพย์ เคทีบี (ประเทศไทย) จำกัด (...        0.761065
# 20  \t  ปตท. หรือหุ้น PTT จะแตกพาร์ หลังมติการประช...        0.738843
# 21            นายธวัชชัย จักรไพศาล รองผู้ว่าการเชื...        0.865626
# 22  นายกีรพัฒน์ เจียมเศรษฐ ผู้ช่วยผู้ว่าการการไฟฟ้...        0.847397
# 23           กลุ่ม บริษัท ปตท. จำกัด ได้กำหนดเป้าห...        0.825948
# 24  \tนายณรงค์ฤทธิ์ ชัยยะราษฎร์ ผู้จัดการแผนกธุรกิ...        0.806076
# 25            นายจักรพงส์ สุเมธโชติเมธา กรรมการผู้...        0.856367
# 26  \tนายอุตตม สาวนายน รัฐมนตรีว่าการกระทรวงอุตสาห...        0.901120
# 27  \t1 ตุลาคม 2563 กรมธุรกิจพลังงาน กำหนดเปลี่ยนช...        0.817724
# 28            นายศรพล ตุลยะเสถียร รองผู้จัดการ หัว...        0.893792
# 29  \tนายจรวย ขันมณี ประธานกรรมการบริหาร  ยานยนต์ ...        0.797605
# 30  \tเมื่อ 11 กุมภาพันธ์ 2564 ปตท. น้ำมันและการค้...        0.851649
# 31            นายสนธิรัตน์ สนธิจิรวงศ์ รัฐมนตรีว่า...        0.866840
# 32  \tนายพงศธร ทวีสิน ประธาน เจ้าหน้าที่บริหาร บริ...        0.851370
# 33            นายกรภัทร วรเชษฐ์ ผู้อำนวยการฝ่ายวิจ...        0.810799
# 34            บริษัทหลักทรัพย์ ฟิลลิป จำกัด ประเมิ...        0.830862
# 35  \tอรรถพล ฤกษ์พิบูลย์ ประธานเจ้าหน้าที่บริหารแล...        0.846864
# 36  \t  บมจ. โกลบอลกรีนเคมิคอล หรือ GGC โดยนายเสกส...        0.837583
# 37  \tนางภรณี ทองเย็น รองกรรมการผู้อำนวยการ สายงาน...        0.828543
# 38            บมจ.ปตท. น้ำมันและการค้าปลีก หรือ OR...        0.852598
# 39            อานิสงส์ราคาน้ำมันเพิ่มบวกท่าทีสหรัฐ...        0.835528
# 40  \t 10 กรกฎาคม 2562 มีพระบรมราชโองการโปรดเกล้าฯ...        0.845253
# 41  \tดร.ศิริ จิระพงษ์พันธ์ รัฐมนตรีว่าการกระทรวงพ...        0.893677
# 42   \tแม้ว่าปลาซุกิจะมีคุณค่าทางโภชนาการ แต่กลับไ...        0.836107
# 43  \tนายภูมินทร์ หะริณสุต ประธานสมาคมเจ้าของเรือไ...        0.899503
# 44           จากกรณีราคาน้ำมันปรับลดฉลองปีใหม่ 255...        0.824140
# 45  \tวันนี้ (27 ก.ค.60) บริษัท ปตท. สำรวจและผลิตป...        0.832039
# 46  \tนางสาวกัญญา ติลกเรืองชัย กรรมการผู้จัดการ บร...        0.800409
# 47  มติคณะกรรมการนโยบายเขตพัฒนาพิเศษภาคตะวันออก (ก...        0.816017
# 48  \tการประกาศใช้บี 10 เป็นรากฐานพลังงานที่รัฐบาล...        0.781601
# 49     \t เปิดแผนพัฒนาอุตสาหกรรมชีวภาพ 1.33 แสนล้า...        0.751465
#
#     BERT_Recall   BERT_F1   ROUGE-1   ROUGE-2   ROUGE-L  ROUGE_Score
# 0      0.820951  0.814421  0.677966  0.497427  0.672316     0.615903
# 1      0.938156  0.936410  0.780142  0.560117  0.732861     0.691040
# 2      0.872554  0.870976  0.695402  0.522593  0.666667     0.628221
# 3      0.835867  0.831359  0.721393  0.492091  0.686567     0.633351
# 4      0.827563  0.845168  0.766917  0.592949  0.746867     0.702244
# 5      0.798919  0.796347  0.554585  0.412860  0.532751     0.500065
# 6      0.848222  0.851233  0.790850  0.653386  0.790850     0.745029
# 7      0.825436  0.838908  0.722543  0.549242  0.716763     0.662850
# 8      0.849457  0.841599  0.724638  0.554517  0.719807     0.666321
