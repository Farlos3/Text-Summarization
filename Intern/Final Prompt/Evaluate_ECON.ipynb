# %%
# !pip install bert-score
# !pip install pythainlp
# !pip install rouge
# !pip install attacut
# Out:
# Collecting bert-score
#   Downloading bert_score-0.3.13-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from bert-score) (2.4.1+cu121)
# Requirement already satisfied: pandas>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from bert-score) (2.1.4)
# Requirement already satisfied: transformers>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from bert-score) (4.44.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from bert-score) (1.26.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from bert-score) (2.32.3)
# Requirement already satisfied: tqdm>=4.31.1 in /usr/local/lib/python3.10/dist-packages (from bert-score) (4.66.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from bert-score) (3.7.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from bert-score) (24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert-score) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert-score) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert-score) (2024.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score) (2024.6.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert-score) (0.24.7)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert-score) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert-score) (2024.9.11)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert-score) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert-score) (0.19.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (3.1.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->bert-score) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->bert-score) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->bert-score) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->bert-score) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.1->bert-score) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.0.0->bert-score) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.0.0->bert-score) (1.3.0)
# Downloading bert_score-0.3.13-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 1.5 MB/s eta 0:00:00
# Installing collected packages: bert-score
# Successfully installed bert-score-0.3.13
# Collecting pythainlp
#   Downloading pythainlp-5.0.4-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: requests>=2.22.0 in /usr/local/lib/python3.10/dist-packages (from pythainlp) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->pythainlp) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->pythainlp) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->pythainlp) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->pythainlp) (2024.8.30)
# Downloading pythainlp-5.0.4-py3-none-any.whl (17.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.9/17.9 MB 61.1 MB/s eta 0:00:00
# Installing collected packages: pythainlp
# Successfully installed pythainlp-5.0.4
# Collecting rouge
#   Downloading rouge-1.0.1-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from rouge) (1.16.0)
# Downloading rouge-1.0.1-py3-none-any.whl (13 kB)
# Installing collected packages: rouge
# Successfully installed rouge-1.0.1
# Collecting attacut
#   Downloading attacut-1.0.6-py3-none-any.whl.metadata (4.0 kB)
# Collecting docopt>=0.6.2 (from attacut)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Collecting fire>=0.1.3 (from attacut)
#   Downloading fire-0.6.0.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.4/88.4 kB 4.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting nptyping>=0.2.0 (from attacut)
#   Downloading nptyping-2.5.0-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from attacut) (1.26.4)
# Requirement already satisfied: pyyaml>=5.1.2 in /usr/local/lib/python3.10/dist-packages (from attacut) (6.0.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from attacut) (1.16.0)
# Collecting ssg>=0.0.4 (from attacut)
#   Downloading ssg-0.0.8-py3-none-any.whl.metadata (762 bytes)
# Requirement already satisfied: torch>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from attacut) (2.4.1+cu121)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from fire>=0.1.3->attacut) (2.4.0)
# Collecting python-crfsuite>=0.9.6 (from ssg>=0.0.4->attacut)
#   Downloading python_crfsuite-0.9.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: tqdm>=4.32.2 in /usr/local/lib/python3.10/dist-packages (from ssg>=0.0.4->attacut) (4.66.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.2.0->attacut) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.2.0->attacut) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.2.0->attacut) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.2.0->attacut) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.2.0->attacut) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.2.0->attacut) (2024.6.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.2.0->attacut) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.2.0->attacut) (1.3.0)
# Downloading attacut-1.0.6-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 4.3 MB/s eta 0:00:00
# Downloading nptyping-2.5.0-py3-none-any.whl (37 kB)
# Downloading ssg-0.0.8-py3-none-any.whl (473 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 473.8/473.8 kB 42.2 MB/s eta 0:00:00
# Downloading python_crfsuite-0.9.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 53.6 MB/s eta 0:00:00
# Building wheels for collected packages: docopt, fire
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13704 sha256=b08eac73dc4ecfd11349869fa4f8736fcbcc291e46c4196ad6994d637f03846f
#   Stored in directory: /root/.cache/pip/wheels/fc/ab/d4/5da2067ac95b36618c629a5f93f809425700506f72c9732fac
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.6.0-py2.py3-none-any.whl size=117030 sha256=992f1fec423e59c4c28051fd80d01b907ce9accd9ad942fa9e4e917f7cf27b3c
#   Stored in directory: /root/.cache/pip/wheels/d6/6d/5d/5b73fa0f46d01a793713f8859201361e9e581ced8c75e5c6a3
# Successfully built docopt fire
# Installing collected packages: python-crfsuite, docopt, nptyping, fire, ssg, attacut
# Successfully installed attacut-1.0.6 docopt-0.6.2 fire-0.6.0 nptyping-2.5.0 python-crfsuite-0.9.10 ssg-0.0.8

# %%
from bert_score import score
from pythainlp.tokenize import word_tokenize
from rouge import Rouge
from tqdm import tqdm
import pandas as pd
import numpy as np
import re

def calculate_bert_score(candidate, reference):
    P, R, F1 = score([candidate], [reference], lang='th', verbose=False)
    bert_score = {
        'precision': float(P[0]),
        'recall': float(R[0]),
        'f1': float(F1[0])
    }
    return bert_score

# %%
def calculate_rouge(candidate, reference, engine=None):
    if engine:
        hypothesis_tokenized = ' '.join(word_tokenize(candidate, engine=engine))
        reference_tokenized = ' '.join(word_tokenize(reference, engine=engine))
    else:  # ใช้ default
        hypothesis_tokenized = ' '.join(word_tokenize(candidate))
        reference_tokenized = ' '.join(word_tokenize(reference))

    rouge = Rouge()
    scores = rouge.get_scores(hypothesis_tokenized, reference_tokenized)[0]

    rouge1_f1 = scores['rouge-1']['f']
    rouge2_f1 = scores['rouge-2']['f']
    rougel_f1 = scores['rouge-l']['f']

    avg_rouge_score = (rouge1_f1 + rouge2_f1 + rougel_f1) / 3

    return rouge1_f1, rouge2_f1, rougel_f1, avg_rouge_score

# %%
def get_text_after_colon(text):
    if ':' in text:
        return text.split(':', 1)[1].strip()
    return text

# %%
files = [
    ('/content/Gemma2-final-prompt.csv', 'Gemma2-final-output.csv'),
    ('/content/LLama3-final-prompt.csv', 'LLama3-final-output.csv'),
    ('/content/Qwen2-final-prompt.csv', 'Qwen2-final-output.csv')
]

# %%
tqdm.pandas()

for input_file, output_file in files:
    df = pd.read_csv(input_file)

    if 'Unnamed: 0' in df.columns:
        df = df.drop('Unnamed: 0', axis=1)

    df['sum_extractive'] = df['sum_extractive'].apply(get_text_after_colon)
    df['sum_abstractive'] = df['sum_abstractive'].apply(get_text_after_colon)

    bert_scores_extractive = df.progress_apply(
        lambda row: calculate_bert_score(row['sum_extractive'], row['extractive']), axis=1
    )

    df['BERT_precision_extractive'] = bert_scores_extractive.apply(lambda x: x['precision'])
    df['BERT_recall_extractive'] = bert_scores_extractive.apply(lambda x: x['recall'])
    df['BERT_f1_extractive'] = bert_scores_extractive.apply(lambda x: x['f1'])

    rouge_scores_extractive = df.progress_apply(
        lambda row: calculate_rouge(row['sum_extractive'], row['extractive'], engine='attacut'), axis=1
    )

    df['ROUGE_1_extractive'] = rouge_scores_extractive.apply(lambda x: x[0])
    df['ROUGE_2_extractive'] = rouge_scores_extractive.apply(lambda x: x[1])
    df['ROUGE_l_extractive'] = rouge_scores_extractive.apply(lambda x: x[2])
    df['avg_ROUGE_extractive'] = rouge_scores_extractive.apply(lambda x: x[3])

    bert_scores_abstractive = df.progress_apply(
        lambda row: calculate_bert_score(row['sum_abstractive'], row['abstractive']), axis=1
    )

    df['BERT_precision_abstractive'] = bert_scores_abstractive.apply(lambda x: x['precision'])
    df['BERT_recall_abstractive'] = bert_scores_abstractive.apply(lambda x: x['recall'])
    df['BERT_f1_abstractive'] = bert_scores_abstractive.apply(lambda x: x['f1'])

    rouge_scores_abstractive = df.progress_apply(
        lambda row: calculate_rouge(row['sum_abstractive'], row['abstractive'], engine='attacut'), axis=1
    )

    df['ROUGE_1_abstractive'] = rouge_scores_abstractive.apply(lambda x: x[0])
    df['ROUGE_2_abstractive'] = rouge_scores_abstractive.apply(lambda x: x[1])
    df['ROUGE_l_abstractive'] = rouge_scores_abstractive.apply(lambda x: x[2])
    df['avg_ROUGE_abstractive'] = rouge_scores_abstractive.apply(lambda x: x[3])

    df.to_csv(output_file, index=False)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# 100%|██████████| 20/20 [00:23<00:00,  1.18s/it]
#   0%|          | 0/20 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/attacut/models/__init__.py:60: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location="cpu"))
# 100%|██████████| 20/20 [00:02<00:00,  7.34it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# 100%|██████████| 20/20 [00:23<00:00,  1.18s/it]
#   0%|          | 0/20 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/attacut/models/__init__.py:60: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location="cpu"))
# 100%|██████████| 20/20 [00:02<00:00,  7.79it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# 100%|██████████| 20/20 [00:22<00:00,  1.14s/it]
#   0%|          | 0/20 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/attacut/models/__init__.py:60: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location="cpu"))
# 100%|██████████| 20/20 [00:02<00:00,  8.57it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# 100%|██████████| 20/20 [00:22<00:00,  1.15s/it]
#   0%|          | 0/20 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/attacut/models/__init__.py:60: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location="cpu"))
# 100%|██████████| 20/20 [00:02<00:00,  7.76it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# 100%|██████████| 20/20 [00:23<00:00,  1.16s/it]
#   0%|          | 0/20 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/attacut/models/__init__.py:60: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location="cpu"))
# 100%|██████████| 20/20 [00:03<00:00,  5.55it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# 100%|██████████| 20/20 [00:24<00:00,  1.23s/it]
#   0%|          | 0/20 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/attacut/models/__init__.py:60: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location="cpu"))
# 100%|██████████| 20/20 [00:02<00:00,  7.02it/s]

# %%
test = pd.read_csv('/content/LLama3-final-output.csv')
test
# Out:
#                                               content  \
# 0   การระดมทุนในตลาดหุ้นไทยอยู่ที่ประมาณ 500,000 ล...
# 1   ช่วงหลายปีที่ผ่านมา บริษัท ปตท. จำกัด (มหาชน) ...
# 2   พริกกะเหรี่ยง          p.singdang60@gmail.com ...
# 3   นายชาญวิทย์ อนัคกุล ประธานเจ้าหน้าที่บริหาร บร...
# 4   บริษัท โกลบอล เพาเวอร์ ซินเนอร์ยี่ จำกัด (มหาช...
# 5   ทางานเป็นลูกหม้อการประปานครหลวง (กปน.) มาร่วม ...
# 6   กรุงเทพธุรกิจ  ปตท.เลื่อนแผนส่งออก LNG เชิงพาณ...
# 7   ปลดล็อกกับดักปั่นที่พุ่งเว่อร์          สมาคมอ...
# 8   ทันหุ้น - GPSC ผลงานโค้งสองสวยรับขายไฟพุ่ง ซดก...
# 9   ทันหุ้น - โบรกส่อง PTT-PTTEP พื้นฐานยังแกร่ง ม...
# 10  ทันหุ้น - KIAT เดินหน้าขยายธุรกิจขนส่งเข้าสู่ต...
# 11  ปจจุบันในประเทศไทย มีสตาร์ตอัพไม่ถึง 10% ที่ได...
# 12  สุธาสินี เฉียงขวา สมาคมตลาดตราสารหนี้ไทย      ...
# 13  กลุ่ม PTT รับผลบวกน้ำมันดิบพุ่ง หลังกลุ่มกบฏฮู...
# 14  ทันหุ้น- ACAP ออกหุ้นกู้ ครั้งที่ 3/2560 เสนอข...
# 15  ปริวัฒน์ หินพลอย          กรุงเทพธุรกิจ       ...
# 16  ชุลีพร อร่ามเนตร          qualitylife4444@gmai...
# 17  นอกจากกระทรวงพลังงานจะเปิดเสรีธุรกิจก๊าซปิโตรเ...
# 18  แนะทำน้ำจืดจากทะเล          กรุงเทพธุรกิจ  ปตท...
# 19  SCN ลงนามสัญญาซ่อมบำรุงรักษาสถานีบริการก๊าซธรร...
#
#                                            extractive  \
# 0   การระดมทุนในตลาดหุ้นไทยอยู่ที่ประมาณ 500,000 ล...
# 1   ปตท. หรือ PTT พยายามสู่ New S-Curve มุ่งธุรกิจ...
# 2   เศรษฐกิจไทยเริ่มฟื้นชัด ส่งออก ท่องเที่ยว ลงทุ...
# 3   นายชาญวิทย์ อนัคกุล ประธานเจ้าหน้าที่บริหาร บร...
# 4   นายชวลิต ทิพพาวนิช ประธานเจ้าหน้าที่บริหารและก...
# 5   ทำงานเป็นลูกหม้อการประปานครหลวง (กปน.) มาร่วม ...
# 6   นายวุฒิกร สติฐิต รองกรรมการ ผู้จัดการใหญ่หน่วย...
# 7   สมาคมอสังหาฯชลบุรีเชียร์รัฐเร่งจัดรูปที่ดินหมื...
# 8   นางสาวสุกิตตี ไชยรักษ์ ผู้จัดการฝ่ายแผนกลยุทธ์...
# 9   นักวิเคราะห์บริษัทหลักทรัพย์ กสิกรไทย จำกัด เผ...
# 10  นายคีรินทร์ ชูธรรมสถิตย์ กรรมการผู้จัดการ บริษ...
# 11  ปัจจุบันในประเทศไทยมีสตาร์ตอัพไม่ถึง 10% ที่ได...
# 12  Chanel และ Burberry เพิ่มไลน์สินค้ารักษ์โลก หุ...
# 13  นายกรภัทร วรเชษฐ์ ผู้อำนวยการฝ่ายวิจัยและบริกา...
# 14  นางสาวสุกัญญา สุขเจริญไกรศรี ประธานเจ้าหน้าที่...
# 15  สถานการณ์ตลาดหุ้นไทยสัปดาห์ที่ผ่านมา (9-13มี.ค...
# 16  วิกฤติกลายเป็นโอกาสสำหรับอุตฯพลาสติก เมื่อสถาน...
# 17  นอกจากกระทรวงพลังงานจะเปิดเสรีธุรกิจก๊าซปิโตรเ...
# 18  นายชาญศิลป์ ตรีนุชกร ประธานเจ้าหน้าที่บริหาร แ...
# 19  ดร.ฤทธี กิจพิพิธ ประธานเจ้าหน้าที่บริหาร บริษั...
#
#                                           abstractive  \
# 0   การระดมทุนในตลาดหุ้นไทยอยู่ที่ประมาณ 500,000 ล...
# 1   ปตท. (PTT)  มุ่งธุรกิจนอนออยล์มากขึ้นสู่ New S...
# 2   เศรษฐกิจไทยเริ่มฟื้นชัด ส่งออก ท่องเที่ยว ลงทุ...
# 3   นายชาญวิทย์ อนัคกุล ประธานเจ้าหน้าที่บริหาร บร...
# 4   นายชวลิต ทิพพาวนิช ประธานเจ้าหน้าที่บริหารและก...
# 5   ทำงานเป็นลูกหม้อการประปานครหลวง (กปน.) มาร่วม ...
# 6   นายวุฒิกร สติฐิต รองกรรมการ ผู้จัดการใหญ่หน่วย...
# 7   สมาคมอสังหาฯชลบุรีเชียร์รัฐเร่งจัดรูปที่ดินหมื...
# 8   นางสาวสุกิตตี ไชยรักษ์ ผู้จัดการฝ่ายแผนกลยุทธ์...
# 9   นักวิเคราะห์บริษัทหลักทรัพย์ กสิกรไทย จำกัด เผ...
# 10  นายคีรินทร์ ชูธรรมสถิตย์ กรรมการผู้จัดการ บริษ...
# 11  ปัจจุบันมีสตาร์ตอัพในประเทศไทยไม่ถึง 10% ที่ได...
# 12  Chanel และ Burberry เพิ่มไลน์สินค้ารักษ์โลก หุ...
# 13  นายกรภัทร วรเชษฐ์ ผู้อำนวยการฝ่ายวิจัยและบริกา...
# 14  นางสาวสุกัญญา สุขเจริญไกรศรี ประธานเจ้าหน้าที่...
# 15  ตลาดหุ้นไทยช่วง 9-13มี.ค.2563 ค่อนข้างผันผวน จ...
# 16  วิกฤติกลายเป็นโอกาสสำหรับอุตฯพลาสติก เมื่อสถาน...
# 17  วันที่ 1 สิงหาคม 2560 นี้ กระทรวงพลังงานจะเปิด...
# 18  นายชาญศิลป์ ตรีนุชกร ประธานเจ้าหน้าที่บริหาร แ...
# 19  วานนี้ (27 มกราคม 2564) ดร.ฤทธี กิจพิพิธ ประธา...
#
#                                        sum_extractive  \
# 0   อย่างไรก็ตาม การระดมทุนในตลาดหุ้นไทยอยู่ที่ประ...
# 1   ปตท. จำกัด (มหาชน) หรือ PTT พยายามออกจากกรอบขอ...
# 2   เรื่องเศรษฐกิจไทยทิศทางใหม่\nประเทศไทยจะเป็นเจ...
# 3    aquí\n\nนายชาญวิทย์ อนัคกุล ประธานเจ้าหน้าที่...
# 4   ค.ศ. 2564\n    ค.ศ. 2564\nบริษัท โกลบอล เพาเวอ...
# 5   ส่วนแรก : วางแผนการดำเนินงาน\nตั้งแต่วันนี้เป็...
# 6   \tพตท.เลื่อนแผนส่งออก LNG เชิงพาณิชย์เป็นไตรมา...
# 7   คู่มือการปลดล็อกกับดักปั่นที่พุ่งเว่อร์\nอย่าง...
# 8   สุence\n\nGPSC ผลงานโค้งสองสวยรับขายไฟพุ่ง ซดก...
# 9   ทันหุ้น - โบรกส่อง PTT-PTTEP พื้นฐานยังแกร่ง\n...
# 10  ๑️ \tKIAT เดินหน้าขยายธุรกิจขนส่งเข้าสู่ตลาดกา...
# 11  เรื่องสถานการณ์สตาร์ทอัพไทยในปัจจุบัน มีสัดส่ว...
# 12  `สุธาสินี เฉียงขวา สมาคมตลาดตราสารหนี้ไทย`\nแบ...
# 13  ราคาน้ำมันดิบพุ่งขึ้น หลังกลุ่มกบฏฮูตีของเยเมน...
# 14  อยู่  ACAP เสนอขายหุ้นกู้ ครั้งที่ 3/2560 วงเง...
# 15  หินพลอย          กรุงเทพธุรกิจ          สถานกา...
# 16  **Program: "Send Plastic Waste Back Home"**\n\...
# 17  ภารกิจลำดับถัดไปคือการเปิดเสรีธุรกิจก๊าซธรรมชา...
# 18  ปตท. เสนอรัฐ เปิดประมูล พีพีพี ดึงน้ำทะเลผลิตน...
# 19   SCN ลงนามสัญญากับ PTT สำหรับการซ่อมบำรุงสถานี...
#
#                                       sum_abstractive  \
# 0   เรื่องที่น่าสนใจเกี่ยวกับการระดมทุนในตลาดหุ้นไ...
# 1   \tปตท. จำกัด (มหาชน) หรือ PTT ได้พยายามออกจากก...
# 2   The Thai tourism industry is expected to conti...
# 3   โดยนายชาญวิทย์ อนัคกุล ประธานเจ้าหน้าที่บริหาร...
# 4   \tบริษัท โกลบอล เพาเวอร์ ซินเนอร์ยี่ จำกัด (มห...
# 5   The Bangkok Metropolitan Waterworks Authority ...
# 6       ปตท.เลื่อนแผนส่งออก LNG เชิงพาณิชย์เป็นไตร...
# 7   ​      รัฐและเอกชนร่วมมือกันพัฒนาเมืองใหม่ในเข...
# 8   ปตท. กลุ่มบริษัทไฟฟ้าที่สำคัญในประเทศไทย ประกอ...
# 9   ผู้ส่องตลาดคาดการณ์ว่า PTT-PTTEP จะมีโอกาสเติบ...
# 10  ทันหุ้น - KIAT เดินหน้าขยายธุรกิจขนส่งเข้าสู่ต...
# 11  เมื่อเริ่มที่จะเป็นสตาร์ตอัพแล้ว จะพบว่าเงินหม...
# 12  การออก ESG bond ของบริษัทแฟชั่นและพลังงานระดับ...
# 13   here.\n\nคาดการณ์ว่าราคาน้ำมันดิบจะพุ่งขึ้นต่...
# 14  ถึงผู้อ่าน\nACAP ออกหุ้นกู้ครั้งที่ 3/2560 เสน...
# 15   here.\n\n\nสถานการณ์ตลาดหุ้นไทยในช่วงสัปดาห์ท...
# 16  The Green Chain (GC) has launched a program to...
# 17   here.\n\nในการเปิดเสรีธุรกิจก๊าซธรรมชาติ (LNG...
# 18  อยู่ระหว่างพิจารณาโครงการผลิตน้ำจืดจากทะเล\nอย...
# 19  \tSCN เข้าสัญญาบริหารสถานีบริการก๊าซธรรมชาติ (...
#
#     BERT_precision_extractive  BERT_recall_extractive  BERT_f1_extractive  \
# 0                    0.829751                0.824108            0.826920
# 1                    0.825765                0.810906            0.818268
# 2                    0.718835                0.719615            0.719225
# 3                    0.805339                0.811308            0.808312
# 4                    0.813427                0.809873            0.811646
# 5                    0.727224                0.740399            0.733752
# 6                    0.850035                0.835051            0.842476
# 7                    0.750685                0.747573            0.749126
# 8                    0.796293                0.790497            0.793384
# 9                    0.802026                0.758633            0.779726
# 10                   0.788247                0.785550            0.786896
# 11                   0.743137                0.754349            0.748701
# 12                   0.836925                0.830722            0.833812
# 13                   0.792251                0.799686            0.795951
# 14                   0.833808                0.791312            0.812004
# 15                   0.775520                0.789072            0.782237
# 16                   0.527283                0.523371            0.525320
# 17                   0.849601                0.829304            0.839330
# 18                   0.791308                0.769010            0.780000
# 19                   0.847610                0.820677            0.833926
#
#     ROUGE_1_extractive  ROUGE_2_extractive  ROUGE_l_extractive  \
# 0             0.575540            0.407895            0.539568
# 1             0.611296            0.344988            0.538206
# 2             0.621212            0.444043            0.595960
# 3             0.693141            0.500000            0.678700
# 4             0.788644            0.629482            0.731861
# 5             0.610811            0.444444            0.551351
# 6             0.706714            0.429561            0.692580
# 7             0.535385            0.268000            0.375385
# 8             0.582090            0.360825            0.417910
# 9             0.640625            0.422392            0.546875
# 10            0.604027            0.340164            0.530201
# 11            0.508961            0.212860            0.336918
# 12            0.649518            0.432990            0.572347
# 13            0.622951            0.404396            0.531148
# 14            0.581818            0.339152            0.429091
# 15            0.549849            0.329939            0.549849
# 16            0.030488            0.003670            0.030488
# 17            0.701887            0.527316            0.671698
# 18            0.579805            0.354776            0.534202
# 19            0.666667            0.370909            0.582011
#
#     avg_ROUGE_extractive  BERT_precision_abstractive  BERT_recall_abstractive  \
# 0               0.507668                    0.793609                 0.798479
# 1               0.498163                    0.787564                 0.793621
# 2               0.553738                    0.580593                 0.548675
# 3               0.623947                    0.827558                 0.821171
# 4               0.716662                    0.863105                 0.843301
# 5               0.535536                    0.570438                 0.545036
# 6               0.609618                    0.826269                 0.850514
# 7               0.392923                    0.733529                 0.728781
# 8               0.453608                    0.817816                 0.822953
# 9               0.536631                    0.830850                 0.810802
# 10              0.491464                    0.783453                 0.777860
# 11              0.352913                    0.694883                 0.656161
# 12              0.551618                    0.791386                 0.783176
# 13              0.519498                    0.694438                 0.675764
# 14              0.450020                    0.834292                 0.805060
# 15              0.476546                    0.751131                 0.781356
# 16              0.021548                    0.590075                 0.539447
# 17              0.633634                    0.814482                 0.817044
# 18              0.489594                    0.757167                 0.741991
# 19              0.539862                    0.871531                 0.863116
#
#     BERT_f1_abstractive  ROUGE_1_abstractive  ROUGE_2_abstractive  \
# 0              0.796037             0.513966             0.378840
# 1              0.790581             0.624658             0.315603
# 2              0.564183             0.020566             0.000000
# 3              0.824352             0.708333             0.404762
# 4              0.853088             0.709220             0.494172
# 5              0.557448             0.053763             0.020305
# 6              0.838216             0.684015             0.443890
# 7              0.731148             0.520900             0.245399
# 8              0.820376             0.702875             0.423237
# 9              0.820703             0.646465             0.307692
# 10             0.780647             0.524476             0.286976
# 11             0.674967             0.235294             0.066667
# 12             0.787260             0.598540             0.339623
# 13             0.684974             0.306250             0.176344
# 14             0.819416             0.738255             0.432432
# 15             0.765945             0.532508             0.346232
# 16             0.563627             0.037383             0.008097
# 17             0.815761             0.743421             0.564612
# 18             0.749502             0.582524             0.339181
# 19             0.867303             0.700422             0.559078
#
#     ROUGE_l_abstractive  avg_ROUGE_abstractive
# 0              0.491620               0.461475
# 1              0.558904               0.499721
# 2              0.020566               0.013710
# 3              0.666667               0.593254
# 4              0.553191               0.585528
# 5              0.053763               0.042610
# 6              0.669145               0.599017
# 7              0.353698               0.373332
# 8              0.581470               0.569194
# 9              0.552189               0.502115
# 10             0.475524               0.428992
# 11             0.176471               0.159477
# 12             0.467153               0.468439
# 13             0.262500               0.248365
# 14             0.570470               0.580386
# 15             0.507740               0.462160
# 16             0.037383               0.027621
# 17             0.671053               0.659695
# 18             0.537217               0.486307
# 19             0.590717               0.616739
