# %% [markdown]
# ### Ollama

# %%
# !ollama list
# Out:
# NAME           ID              SIZE      MODIFIED
# llama3.1:8b    42182419e950    4.7 GB    6 days ago
# llama3:8b      365c0bd3c000    4.7 GB    8 days ago
# qwen2:7b       dd314f039b9d    4.4 GB    9 days ago
# gemma2:9b      ff02c3702f32    5.4 GB    9 days ago

# %%
from langchain_community.chat_models import ChatOllama
from langchain.prompts import ChatPromptTemplate, SystemMessagePromptTemplate, HumanMessagePromptTemplate

# %%
local_model = "llama3:8b"
# llm = ChatOllama(model=local_model)
llm = ChatOllama(model=local_model, use_gpu=True)

# %%
llm
# Out:
# ChatOllama(model='llama3:8b')

# %%
import pandas as pd

df = pd.read_csv(
    r'F:\AI\Super AI SS4\Level 3 - INTERN\Jupyter Notebook\Latest-Dataset-Model-Generate\Random\Latest-20-random.csv')

df.shape
# Out:
# (20, 4)

# %%
df.head()
# Out:
#                                              content  \
# 0            มิติหุ้น SKE คอนเฟิร์มรายได้ปี 62 เต...
# 1            ผลกระทบจากเชื้อไวรัสโคโรนา (โควิด-19...
# 2            องค์การส่งเสริมกิจการโคนมแห่งประเทศไ...
# 3            กระทรวงพลังงานใช้เวลาไป 1 ปี กับอีก ...
# 4            นับเป็นอีกหนึ่งโครงการดีๆ ที่เปิดโอก...
#
#                                           extractive  \
# 0  \t  บมจ.สากล เอนเนอยี หรือ SKE โดย นายจักรพงส์...
# 1            ผลกระทบจากโควิด-19 ผลต่อกำไรของบริษั...
# 2            ดร.ณรงค์ฤทธิ์ วงศ์สุวรรณ ผู้อำนวยการ...
# 3     \tกระทรวงพลังงานใช้เวลา 1 ปี 7 เดือน แก้ปมร...
# 4      \t อีกหนึ่งโครงการดีๆ ที่เปิดโอกาสให้เด็ก ...
#
#                                          abstractive  index_original
# 0  \tนายจักรพงส์ สุเมธโชติเมธา กรรมการผู้จัดการให...            3017
# 1  \tนายมงคล พ่วงเภตรา ผู้ช่วยกรรมการผู้จัดการ ฝ่...            2844
# 2            ดร.ณรงค์ฤทธิ์ วงศ์สุวรรณ ผู้อำนวยการ...            2055
# 3     \tกระทรวงพลังงานใช้เวลา 1 ปี 7 เดือน แก้ปมร...             199
# 4   \tโครงการประกวดศิลปกรรม ปตท. จากการสนับสนุนขอ...             216

# %% [markdown]
# ### Summarize

# %% [markdown]
# #### Abstractive

# %%
def summarize_abstractive(text, llm):
    system_template = """You are an AI specialized in abstractive summarization for economic news articles."""

    prompt = """Your task is to create an abstractive summary of the given news article. Follow these guidelines:
    1. Summarize the content in Thai.
    2. Use neutral, and clear language while maintaining a formal tone.
    3. Use \t at the beginning of each paragraph to create indentation.
    4. Each paragraph should present a different point.
    5. DO NOT leave blank lines between paragraphs. All paragraphs must be continuous with no blank lines.
    6. Explain in detail the essence and main points of the article.
    7. Ensure the summary is coherent and flows well as a standalone piece.
    8. Preserve all important proper nouns such as names of people, companies, or organizations.
    9. Organize the content logically, which may differ from the original article's structure if it improves clarity.
    10. Synthesize information from different parts of the article when appropriate.
    11. DO NOT include any examples or case studies in the summary.
    
    IMPORTANT:
    - Please verify the accuracy of the information and present it in a neutral manner, without personal opinions or bias.
    - Focus on creating a coherent, flowing summary that captures the main ideas without direct quoting.
    - The summary has retained its original meaning and context.
    
    Article to summarize:
    {text}
    """

    system_message_prompt = SystemMessagePromptTemplate.from_template(system_template)
    human_message_prompt = HumanMessagePromptTemplate.from_template(prompt)

    chat_prompt = ChatPromptTemplate.from_messages([system_message_prompt, human_message_prompt])
    messages = chat_prompt.format_messages(text=text)

    return llm.invoke(messages).content

# %% [markdown]
# #### Extractive

# %%
def summarize_extractive(text, llm):
    system_template = """You are an AI specialized in extractive summarization for economic news articles."""

    prompt = """Your task is to summarize the key content from the given news article. Follow these guidelines:
    1. Summarize the content in Thai.
    2. Use \t at the beginning of each paragraph to create indentation.
    3. DO NOT leave blank lines between paragraphs. All paragraphs must be continuous with no blank lines.
    4. Focus on main points and important secondary points.
    5. Provide explanations of the article’s key topics without going into too much detail.
    6. Preserve all proper nouns such as names of people, companies, or organizations.
    7. Use 2-3 key sentences from the original article for each point.
    8. Maintain the original meaning and context.
    9. Arrange the content in the same order as presented in the original article.
    10. Reduce redundancy by combining similar points or information.
    11. DO NOT include any examples in the summary.

    IMPORTANT: 
    - DO NOT include any examples or case studies in the summary. Focus only on the main points and key information.

    Article to summarize:
    {text}
    """

    system_message_prompt = SystemMessagePromptTemplate.from_template(system_template)
    human_message_prompt = HumanMessagePromptTemplate.from_template(prompt)

    chat_prompt = ChatPromptTemplate.from_messages([system_message_prompt, human_message_prompt])
    messages = chat_prompt.format_messages(text=text)

    return llm.invoke(messages).content

# %%
# !ollama list
# Out:
# NAME           ID              SIZE      MODIFIED
# llama3.1:8b    42182419e950    4.7 GB    6 days ago
# llama3:8b      365c0bd3c000    4.7 GB    8 days ago
# qwen2:7b       dd314f039b9d    4.4 GB    9 days ago
# gemma2:9b      ff02c3702f32    5.4 GB    9 days ago

# %%
# !ollama list
# Out:
# NAME           ID              SIZE      MODIFIED
# llama3.1:8b    42182419e950    4.7 GB    6 days ago
# llama3:8b      365c0bd3c000    4.7 GB    8 days ago
# qwen2:7b       dd314f039b9d    4.4 GB    9 days ago
# gemma2:9b      ff02c3702f32    5.4 GB    9 days ago

# %%
import re
import pandas as pd
import numpy as np
from langchain_community.chat_models import ChatOllama
from langchain_community.llms import Ollama
from langchain.prompts import ChatPromptTemplate, SystemMessagePromptTemplate, HumanMessagePromptTemplate
from tqdm import tqdm
import textgrad as tg
from textgrad.variable import Variable
from textgrad.optimizer import TextualGradientDescent
from textgrad.loss import TextLoss
from textgrad.engine import get_engine

# Initialize models
summary_model = "gemma2:9b"
llm_summarizer = ChatOllama(model=summary_model, use_gpu=True)

ollama_engine = Ollama(model="llama3.1:8b")
tg.set_backward_engine(ollama_engine, override=True)

def summarize_with_prompts(llm_summarizer, system_prompt, human_prompt, text):
    system_message = SystemMessagePromptTemplate.from_template(system_prompt)
    human_message = HumanMessagePromptTemplate.from_template(human_prompt)
    chat_prompt = ChatPromptTemplate.from_messages([system_message, human_message])
    messages = chat_prompt.format_messages(text=text)
    
    response = llm_summarizer.invoke(messages)
    return response.content

def evaluate_summary(ollama_engine, generated_summary, reference_summary):
    eval_prompt = f"""You are an AI that evaluates the quality of summaries. Compare the generated summary with the reference summary and provide a score between 0 and 1, where 1 is perfect. Consider factors such as content coverage, conciseness, and clarity. Explain your reasoning briefly, then provide the score.

Generated: {generated_summary}
Reference: {reference_summary}

Explanation and Score:"""
    
    response = ollama_engine(eval_prompt)
    match = re.search(r'\d+(\.\d+)?', response)
    if match:
        try:
            score = float(match.group())
            print(f"Evaluation explanation: {response}")
            return score
        except ValueError:
            print(f"Could not convert to float: {match.group()}")
            return 0
    else:
        print(f"Could not extract score from: {response}")
        return 0

def evaluate_prompts(llm_summarizer, ollama_engine, system_prompt, human_prompt, df):
    scores = []
    for _, row in df.iterrows():
        summary = summarize_with_prompts(llm_summarizer, system_prompt, human_prompt, row['generated_summary'])
        score = evaluate_summary(ollama_engine, summary, row['reference_summary'])
        scores.append(score)
    
    return np.mean(scores)

def optimize_prompts(llm_summarizer, ollama_engine, initial_system_prompt, initial_human_prompt, df, epochs):
    system_prompt = Variable(initial_system_prompt, role_description="System prompt for summarization")
    human_prompt = Variable(initial_human_prompt, role_description="Human prompt for summarization")
    optimizer = TextualGradientDescent([system_prompt, human_prompt]) 
    
    best_score = 0
    best_system_prompt = initial_system_prompt
    best_human_prompt = initial_human_prompt
    
    # Keep track of all prompts
    prompt_history = []

    for epoch in tqdm(range(epochs), desc="Optimizing prompts"):
        try:
            current_score = evaluate_prompts(llm_summarizer, ollama_engine, system_prompt.value, human_prompt.value, df)
        
            # Save the prompts of the current epoch
            prompt_history.append({
                "epoch": epoch+1,
                "system_prompt": system_prompt.value,
                "human_prompt": human_prompt.value,
                "score": current_score
            })
        
            if current_score > best_score:
                best_score = current_score
                best_system_prompt = system_prompt.value
                best_human_prompt = human_prompt.value
        
            print(f"Epoch {epoch+1}/{epochs} | Current Score: {current_score:.4f} | Best Score: {best_score:.4f}")
            print(f"Current System Prompt: {system_prompt.value[:100]}...")
            print(f"Current Human Prompt: {human_prompt.value[:100]}...")
            print("-" * 50)
        
            loss = 1 - current_score
            loss_var = Variable(str(loss), role_description="Loss for optimization")
            loss_var.backward()
            optimizer.step()
            optimizer.zero_grad()
            
            # Add some randomness to avoid local optima
            if epoch % 5 == 0:
                system_prompt.value += " " + ollama_engine("Generate a short, relevant phrase to add to a summarization system prompt.")
                human_prompt.value += " " + ollama_engine("Generate a short, relevant phrase to add to a summarization human prompt.")
        
        except Exception as e:
            print(f"Error occurred: {e}")
            print(f"Current system prompt: {system_prompt.value}")
            print(f"Current human prompt: {human_prompt.value}")
    
    return best_system_prompt, best_human_prompt, best_score, prompt_history

def read_csv_file(file_path):
    df = pd.read_csv(file_path)
    
    # เลือกเฉพาะคอลัมน์ที่ต้องการ
    df = df[['sum_extractive', 'extractive']]
    
    # ตั้งชื่อคอลัมน์ใหม่เพื่อความชัดเจน
    df.columns = ['generated_summary', 'reference_summary']
    
    return df

def run_optimization(file_path):
    initial_system_prompt = """You are an AI specialized in extractive summarization for economic news articles."""
    initial_human_prompt = """Your task is to summarize the key content from the given news article. Follow these guidelines:
    1. Summarize the content in Thai.
    2. Use \t at the beginning of each paragraph to create indentation.
    3. DO NOT leave blank lines between paragraphs. All paragraphs must be continuous with no blank lines.
    4. Focus on main points and important secondary points.
    5. Provide explanations of the article’s key topics without going into too much detail.
    6. Preserve all proper nouns such as names of people, companies, or organizations.
    7. Use 2-3 key sentences from the original article for each point.
    8. Maintain the original meaning and context.
    9. Arrange the content in the same order as presented in the original article.
    10. Reduce redundancy by combining similar points or information.
    11. DO NOT include any examples in the summary.

    IMPORTANT: 
    - DO NOT include any examples or case studies in the summary. Focus only on the main points and key information.

    Article to summarize:
    {text}"""
    
    df = read_csv_file(file_path)
    best_system_prompt, best_human_prompt, best_score, prompt_history = optimize_prompts(llm_summarizer, ollama_engine, initial_system_prompt, initial_human_prompt, df, epochs=4)
    
    print("\nBest System Prompt:", best_system_prompt)
    print("\nBest Human Prompt:", best_human_prompt)
    print(f"\nBest Score: {best_score:.4f}")
    
    # Print full prompt history
    print("\nPrompt History:")
    for entry in prompt_history:
        print(f"Epoch {entry['epoch']}:")
        print(f"System Prompt: {entry['system_prompt']}")
        print(f"Human Prompt: {entry['human_prompt']}")
        print(f"Score: {entry['score']:.4f}")
        print("-" * 50)
    
    return prompt_history

if __name__ == "__main__":
    file_path = r'F:\AI\Super AI SS4\Level 3 - INTERN\Jupyter Notebook\Latest-Dataset-Model-Generate\Edit-Prompt\final\Gemma2-final-output.csv'
    optimize = run_optimization(file_path)
    print(optimize)
# Out:
# Optimizing prompts:   0%|          | 0/4 [00:00<?, ?it/s]C:\Users\09350\AppData\Local\Temp\ipykernel_33956\1883060667.py:38: LangChainDeprecationWarning: The method `BaseLLM.__call__` was deprecated in langchain-core 0.1.7 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   response = ollama_engine(eval_prompt)
# Evaluation explanation: The generated summary has some similarities with the reference summary, but it lacks crucial details. Here's a brief explanation of my reasoning:
#
# * Content coverage: The generated summary covers only 50% of the content in the reference summary, missing key points such as the total market capitalization at the end of 2020 and the specific performance of SCGP.
# * Conciseness: The generated summary is concise, but it's also incomplete. It fails to provide essential information, making it difficult to understand the overall context.
# * Clarity: The language used in the generated summary is clear, but it's not as accurate as the reference summary.
#
# Score: 0.6/1
#
# The score indicates a moderate level of quality, but with significant room for improvement. The generated summary needs to provide more comprehensive information and accurately convey the details from the original text.
# Evaluation explanation: The generated summary is quite close to the reference summary. However, there are some minor discrepancies in terms of content coverage and clarity.
#
# Score: 0.8
#
# Reasoning:
#
# * Content coverage: Both summaries cover the main points of PTT's new business ventures, including New S-Curve, retail business through OR, cafes, and healthcare services. The generated summary also mentions the spin-off plan, which is not present in the reference summary.
# * Clarity: While both summaries are easy to read, the reference summary provides a clearer structure and uses more concise sentences.
# * Concision: Both summaries are similar in length, but the reference summary conveys its message more efficiently.
# * Similarities and differences: The generated summary has some minor errors and inaccuracies compared to the reference summary. For example, it mentions "PTT ยังรุกธุรกิจร้านคาเฟ่ อเมซอน ที่ประสบความสำเร็จ" (PTT is also expanding its cafe business, Amazon, which was successful) instead of stating that PTT's cafe business, Amazon, has been successful.
#
# Overall, the generated summary provides a good overview of PTT's new business ventures but could benefit from some improvement in terms of content coverage and clarity to reach a perfect score.
# Evaluation explanation: I'd be happy to evaluate the quality of the generated summary.
#
# **Comparison with Reference Summary**
#
# The generated summary covers some key points from the reference summary, such as:
#
# * Economic growth in Thailand (content coverage: 70%)
# * AEC's importance (content coverage: 80%)
# * Business leaders' support for AEC (content coverage: 50%)
# * Airline and hotel industry news (content coverage: 60%)
#
# However, the generated summary lacks some important details from the reference summary, such as:
#
# * Specific quotes or opinions from business leaders (conciseness: -30%)
# * Details about the tourism design competition (content coverage: -20%)
# * News about Kintetsu Railway's unlimited travel ticket sale (content coverage: -10%)
#
# The generated summary is concise and easy to read, but it may be too brief and lacks some important context. (clarity: 80%)
#
# **Overall Score**
#
# Based on the comparison with the reference summary, I would give the generated summary a score of **0.65/1**.
#
# While it covers some key points and is concise, it lacks some important details and context, which makes it less informative and useful than the reference summary.
# Evaluation explanation: After comparing the generated summary with the reference summary, I would give a score of 0.8 out of 1.
#
# The generated summary covers most of the key points mentioned in the reference summary, including:
#
# * The expected growth of PRM's revenue and profit (12% increase)
# * The focus on FSU business and tanker business
# * The investment in additional FSU vessels (2 new vessels + existing 5 vessels = 7 vessels)
# * The addition of 6 new tanker vessels to the fleet
# * The mixed performance of other businesses, including offshore business and ship management business
#
# However, there are some minor discrepancies and omissions:
#
# * The generated summary does not mention the expected growth rate of PRM's revenue and profit in 2022 (12% increase)
# * It also omits some details about the investment plan for 2022 (6 billion THB) and the planned acquisition of additional shares in Big Sea
# * The tone of the generated summary is slightly more concise and less detailed than the reference summary
#
# Overall, while the generated summary does a good job of capturing the main points, it could benefit from a bit more attention to detail and concision. Hence the score of 0.8 out of 1.
# Evaluation explanation: Here's the comparison of the generated summary with the reference summary:
#
# **Content Coverage:** The generated summary covers 80% of the key points in the reference summary, missing some details such as the specific number of cells (40 vs 32) and the mention of a policy (S-Curves).
#
# **Conciseness:** The generated summary is concise and to the point, but it lacks some of the nuances and specifics found in the reference summary.
#
# **Clarity:** Both summaries are clear, but the generated one could benefit from more precise language and fewer vague phrases.
#
# **Overall Score:** 0.75/1
#
# The generated summary does a good job of capturing the main points of the original text, including the partnership between GPSC and 24 M Technologies, the development of new battery technology, and its benefits. However, it falls short in terms of content coverage and conciseness, missing some key details and being a bit too general at times.
# Evaluation explanation: **Content Coverage:** The generated summary covers about 70% of the key points from the reference summary, including the background information on Prinya Yamasmit's experience with the Waterworks Department, his plans to implement the "G้าวสู่ Digital MWA" vision, and specific initiatives such as reducing water installation costs by 50%, promoting e-Service, and investing in new infrastructure.
#
# **Conciseness:** The generated summary is concise and to the point, but it omits some details from the reference summary. For example, the reference summary mentions the target of reducing water leakage to 19% within a specific timeframe, which is not mentioned in the generated summary.
#
# **Clarity:** The language used in the generated summary is clear and easy to understand, making it accessible to a wide audience.
#
# Considering these factors, I would give the generated summary a score of **0.7 out of 1**. While it covers most of the essential information from the reference summary, it could be more comprehensive and detailed, particularly regarding specific initiatives and timelines.
# Evaluation explanation: Here's a comparison of the generated summary with the reference summary, along with my evaluation:
#
# **Content Coverage**: The generated summary covers about 70-80% of the content in the reference summary. It mentions the delay in commercial LNG export, the reason for the delay (increase in LNG price and decrease in electricity demand), and PTT's target market (CLMV and southern China). However, it misses some details such as the specific projects mentioned in the reference summary.
#
# **Conciseness**: The generated summary is concise but could be shorter. It contains a few unnecessary words and phrases that make it slightly longer than necessary.
#
# **Clarity**: The language used in the generated summary is clear and easy to understand, although there are some minor errors in grammar and syntax.
#
# Considering these factors, I would give the generated summary a score of **0.8/1**. It's a good effort, but could be improved with more attention to detail and conciseness.
# Evaluation explanation: Here's a comparison between the generated summary and the reference summary:
#
# **Content Coverage**: The generated summary covers most of the key points from the reference summary, but it lacks some specific details such as the development of a new city (ศรีราชา-ชลบุรี) and the collaboration with PTT to develop a project. Score: 0.8
#
# **Conciseness**: Both summaries are concise, but the generated summary is slightly longer than the reference summary. The reference summary provides more direct quotes from the source, making it easier to read and understand. Score: 0.7
#
# **Clarity**: The clarity of both summaries is good, but the reference summary provides more context and background information. The generated summary assumes some prior knowledge about the topic. Score: 0.8
#
# Overall Score: **0.78**
#
# The generated summary is a good attempt to summarize the original article, but it could be improved by providing more specific details and context.
# Evaluation explanation: Here's the comparison:
#
# **Content Coverage:** The generated summary covers about 70% of the key points from the reference summary. It misses out on specific details such as the solar farm investment in Thailand, the battery manufacturing project, and the timeline for submitting the capital raise plan to the board.
#
# **Conciseness:** The generated summary is concise, but it's also somewhat vague. Some sentences feel like they're repeating information that's already been mentioned. This brings the conciseness score down to about 0.8 out of 1.
#
# **Clarity:** Clarity-wise, the generated summary does a decent job. However, some sentences are still a bit wordy or unclear in their wording. Overall, I'd give clarity a score of around 0.9 out of 1.
#
# **Score:** Taking all these factors into account, I'd give the generated summary a score of **0.85** out of 1. It's not perfect, but it does a good job summarizing the main points from the reference text!
# Evaluation explanation: The generated summary is 0.8 out of 1 in terms of quality.
#
# Reasoning:
#
# * Content coverage: The generated summary covers the main points mentioned in the reference, including the potential outcomes of OPEC's meeting on oil production cuts, the impact on PTT and PTTEP shares, and the company's management performance.
# * Conciseness: The generated summary is concise but not too short, conveying the essential information without unnecessary details. However, it lacks some nuances and specific data points present in the reference.
# * Clarity: The language used in the generated summary is clear and easy to understand, making it accessible to readers who may not be familiar with the topic.
#
# Score: 0.8
#
# Note that while the generated summary is good, there are small differences in wording and minor omissions compared to the reference. A perfect score would require a more comprehensive and nuanced summary that mirrors the original content exactly.
# Evaluation explanation: I'll evaluate the generated summary against the reference summary.
#
# **Content Coverage:** The generated summary covers the main points of the reference, including KIAT's win of a 5-year contract for LNG transportation from PTT, their experience in hazardous goods transportation, and positive financial performance. However, it lacks specific details about the route and equipment used for the project.
#
# **Conciseness:** The generated summary is concise but slightly shorter than the reference summary. It omits some key points, such as the Guardian System installed on KIAT's vehicles and the breakdown of costs in the second quarter of 2017.
#
# **Clarity:** Both summaries are written in clear Thai language, making it easy to understand the content. However, the generated summary is less detailed than the reference.
#
# Based on these factors, I would give the generated summary a score of **0.75** (out of 1). While it captures the essence of the reference summary, it lacks some important details and specific information about the project.
# Evaluation explanation: The generated summary has a score of 0.85.
#
# Reasoning:
#
# * Content coverage: The generated summary covers the main points, including the low success rate of startups in Thailand (less than 10% reaching Series A funding), the challenges faced by startups in raising funds, and the importance of financial management and partnership models.
# * Conciseness: The generated summary is concise, but slightly longer than ideal. It could be condensed further while still maintaining the essential information.
# * Clarity: The language used is clear, but there are a few minor errors in grammar and vocabulary (e.g., "ไม่ถึง 10% ของสตาร์ตอัพทั้งหมด" instead of "ไม่ถึง 10% ที่ได้รับการลงทุน"). However, overall, the summary is well-structured and easy to follow.
#
# The reference summary provides more detailed information and specific examples from various startups, but the generated summary still captures the essence of the key points. With a few minor adjustments, it could be improved further to reach a score closer to 1.
# Evaluation explanation: The generated summary covers the key points of the reference summary, including the definition of ESG bonds, examples of companies that have issued them (such as Chanel, Burberry, Saudi Electricity, Daimler AG, and Thai government agencies), and the increasing trend of issuing ESG bonds. However, there are some minor differences in details and clarity.
#
# The generated summary is concise and to the point, but it lacks some specific examples and details present in the reference summary, such as the exact usage of funds for Chanel and Burberry's sustainability bonds. Additionally, some sentences in the generated summary feel a bit disconnected from each other.
#
# Score: 0.8
#
# Reasoning:
#
# * Content coverage: 0.7 (the generated summary covers the main points, but lacks some specific details)
# * Conciseness: 0.9 (the generated summary is concise and to the point)
# * Clarity: 0.8 (some sentences feel a bit disconnected from each other)
#
# Note that this score is based on the provided reference summary as the "gold standard" of quality, and may not reflect real-world evaluation criteria used in professional settings.
# Evaluation explanation: **Score: 0.8**
#
# The generated summary covers the main points of the reference, including the attack on Saudi Arabia's oil facilities by Yemen's Houti rebels, the increase in global crude oil prices to $70 per barrel, and the positive impact on Thai energy stocks. However, it misses some details from the reference, such as:
#
# * The specific companies mentioned (PTTEP, PTTGC, BANPU) are not fully elaborated upon.
# * The quote from Mr. Witthaya Kurovath is missing a crucial detail about the expected impact on global oil prices.
# * The tone of the generated summary is more concise and focused on the positive impact, whereas the reference provides a more balanced view with cautionary notes.
#
# Overall, while the generated summary is a good effort, it lacks some depth and nuance compared to the original.
# Evaluation explanation: **Score:** 0.7
#
# The generated summary covers the main points of the reference summary, including:
#
# * ACAP's plan to issue a new bond (หุ้นกู้) with a maximum value of 500 million THB
# * The bond will have a 2-year term and an interest rate of 6% per annum
# * The funds from the bond issuance will be used to support ACAP's expansion plans, including increasing its loan portfolio to 20 billion THB in 5 years
#
# However, there are some differences:
#
# * The reference summary provides more context on ACAP's financial performance and credit rating (BBStable), which is not mentioned in the generated summary
# * The reference summary also mentions the planned listing of Global Service Center Co., Ltd. on the MAI stock exchange, which is not included in the generated summary
# * The language used in the generated summary is simpler and more concise than the reference summary
#
# Overall, while the generated summary covers the main points, it lacks some details and context that are present in the reference summary. Hence the score of 0.7.
# Evaluation explanation: The generated summary and reference summary share similar content coverage, but the reference summary provides more detailed information about the impact of COVID-19 on the Thai stock market, including specific data points such as the 28.54% decline in the SET Index and the 450.93-point drop.
#
# However, the generated summary does not mention this specific information, instead focusing on the general trend of the market's volatility. Additionally, the reference summary provides more context about the temporary halt in trading due to market volatility.
#
# In terms of conciseness, the generated summary is slightly more concise than the reference summary, but still conveys the main points effectively. The clarity of both summaries is good, with clear and simple language used.
#
# Overall, I would give the generated summary a score of 0.7 out of 1. While it captures the essence of the market's volatility and the buying activity by corporate executives, it lacks some specific details and context provided in the reference summary.
# Evaluation explanation: The generated summary and the reference summary share similar content, but there are some differences in terms of conciseness and clarity. Here's a breakdown:
#
# * Content coverage: Both summaries cover the main points about GC's efforts to reduce plastic waste, promote recycling, and encourage sustainable practices.
# * Conciseness: The generated summary is slightly more concise than the reference summary, but it misses out on some specific details and quotes from the original text.
# * Clarity: While both summaries are clear in their own right, the reference summary provides more context and supporting information to help readers understand the issue and GC's approach.
#
# Overall, I would give the generated summary a score of 0.75/1. It's well-structured and covers the key points, but it could benefit from more detail and clarity to match the quality of the reference summary.
# Evaluation explanation: Here's a comparison between the generated summary and the reference summary:
#
# **Content Coverage:** The generated summary covers 80% of the content in the reference summary, missing some details such as the context for opening up the gas business and the importance of having both long-term and short-term contracts.
#
# **Conciseness:** The generated summary is concise, covering the main points in just a few sentences. However, it could be improved by condensing the information further to make it more readable.
#
# **Clarity:** The language used in the generated summary is clear, but it could benefit from some minor tweaks to improve its flow and coherence.
#
# Score: 0.8/1
#
# The generated summary provides a good overview of the main points, but it lacks some context and details that are present in the reference summary. With some minor adjustments, it can be improved to make it more comprehensive and easier to read.
# Evaluation explanation: **Score:** 0.8
#
# The generated summary is quite accurate, but it misses a few details present in the reference summary. Here's why:
#
# * Content coverage: The generated summary covers most of the main points from the reference summary, including PTT's preparation for drought, PPP proposal for seawater desalination, and plans to reduce natural gas imports.
# * Clarity: Both summaries are written clearly and concisely.
# * Conciseness: While both summaries are concise, the generated one is a bit shorter than the reference.
#
# However, I deduct points because:
#
# * The generated summary does not mention specific locations like Mabtaput and Laemchabang, which are mentioned in the reference.
# * It also omits the context of PTT's reduced reliance on Chinese markets and potential implications for Thailand's industry.
# * Minor errors in translation and phrasing occur (e.g., "ทรัพยากรสำคัญที่หล่อเลี้ยงภาคอุตสาหกรรมและการอุปโภคบริโภค" is translated as "key resources supporting industrial and consumer sectors").
#
# Overall, the generated summary captures the essence of PTT's plans and initiatives but misses some important details present in the reference.
# Evaluation explanation: To evaluate the generated summary, I compare it with the reference summary. Here's a brief explanation:
#
# **Content Coverage**: Both summaries cover the main points of the news: SCN signing an agreement with PTT for station maintenance, value, duration, and benefits to SCN's performance.
#
# **Conciseness**: The generated summary is concise (13 sentences) while the reference summary is also compact (4 paragraphs, approximately 80 words). However, the reference summary provides more specific details about SCN's role in the industry.
#
# **Clarity**: Both summaries are clear and easy to understand. However, the reference summary uses a bit more formal language, which might make it slightly easier for non-experts to grasp the context of SCN's significance in the natural gas market.
#
# Based on these factors, I'd give the generated summary a score of 0.7 out of 1. The score reflects that the generated summary effectively captures the main points and structure of the news but may lack some specific details found in the reference summary.
# Epoch 1/4 | Current Score: 26.7450 | Best Score: 26.7450
# Current System Prompt: You are an AI specialized in extractive summarization for economic news articles....
# Current Human Prompt: Your task is to summarize the key content from the given news article. Follow these guidelines:
#     ...
# --------------------------------------------------
# Optimizing prompts:  25%|██▌       | 1/4 [48:10<2:24:32, 2890.79s/it]
# Evaluation explanation: The generated summary is quite different from the reference summary. While it mentions a positive sentiment towards the "Key takeaways only" option, it does not provide any information about the Thai stock market or companies going public.
#
# In contrast, the reference summary provides detailed information about the Thai stock market's fundraising efforts, the performance of various companies, and trends in the market. It also mentions specific companies that have gone public and their respective financial data.
#
# Given this comparison, I would give the generated summary a score of 0.2 out of 1. The content coverage is minimal, conciseness is not an issue since it's too short to be concise, and clarity is lacking as it doesn't provide any meaningful information about the topic. Overall, the generated summary does not capture the essence of the reference summary or provide useful insights on its own.
# Evaluation explanation: The generated summary is not relevant to the reference article, which discusses PTT's business strategy and expansion into new areas such as healthcare and life science. The generated summary only talks about summarizing articles.
#
# Content coverage: 0 (does not cover any part of the reference article)
#
# Conciseness: 1 (the generated summary is brief and to the point)
#
# Clarity: 0 (the generated summary is unrelated to the reference article, making it unclear what it refers to)
#
# Score: 0
# Evaluation explanation: **Score: 0.4**
#
# The generated summary provides a brief introduction to summarization, highlighting the benefits of using "**"The key points distilled:"** as a summarization prompt. However, it does not attempt to summarize the reference text.
#
# While the generated summary is clear and concise, it lacks content coverage and clarity in relation to the reference text. The score reflects this significant gap between the two summaries.
# Evaluation explanation: **Score: 0.4**
#
# The generated summary focuses on the general prompt and additional options, but does not relate to the content of the reference summary. The generated text is about summarization in general, whereas the reference summary is a detailed report about the business performance and investment plans of a specific company (PRM). The two texts do not share common content or themes, making it difficult for the AI to find similarities.
#
# However, if I were to consider only the context of summarization prompts, the generated text does mention "clear", "concise", and "essential information", which are relevant qualities of a good summary. But still, this is far from being a faithful representation of the reference summary, hence the low score.
#
# If you'd like me to re-evaluate with a different perspective or consider an alternative scoring method, please let me know!
# Evaluation explanation: Let's evaluate the generated summary.
#
# The generated summary is concise, but it only mentions one of the main points from the article. It correctly identifies the clarity and conciseness of "Summarize the main points" as an instruction to focus on essential information. However, it fails to mention other important aspects such as GPSC's investment in 24 M Technologies, the benefits of 24 M batteries, and the plan for a pilot plant.
#
# Compared to the reference summary, which covers multiple key points from the article, the generated summary is missing crucial content coverage (score: 0.4). While it is clear and concise, its brevity comes at the cost of omitting important information.
#
# Score: 0.5
# Evaluation explanation: Here's my evaluation of the generated summary compared to the reference summary:
#
# The generated summary focuses on the process of summarization, using the phrase "distilled" to convey the idea of extracting key information. However, it does not provide any actual content from the article.
#
# In contrast, the reference summary provides a detailed overview of the interview with the head of the water and sewage department in Bangkok, discussing their plans for digital transformation, key projects, and initiatives to improve service quality.
#
# Given the significant difference in content coverage, I would give the generated summary a score of 0.2 out of 1. The reference summary is much more comprehensive and informative, while the generated summary only touches on the process of summarization without providing any actual information from the article.
# Evaluation explanation: Let's evaluate the generated summary against the reference summary.
#
# The generated summary mentions "Key takeaways only" and expresses eagerness to test summarizing skills, but it doesn't provide any actual information about a specific article or topic. In contrast, the reference summary provides detailed information about PTT's plan to export LNG, citing specific plans, markets, and energy consumption trends in Thailand.
#
# Given this comparison, I would give the generated summary a score of 0. The summary fails to cover content related to the actual article, is not concise in relation to the topic, and lacks clarity on what information is being summarized.
# Evaluation explanation: **Content Coverage:** The generated summary barely mentions the key points of the article, focusing instead on a prompt fitting into human summarization. It fails to cover any specific information about the economic news articles or the project mentioned in the reference.
#
# **Conciseness:** The generated text is not concise at all, as it does not provide a brief summary of the content but rather discusses its own methodology and prompt suitability.
#
# **Clarity:** The clarity score would be low due to the irrelevance and vagueness of the generated response in relation to the reference article's topic. It lacks any clear statement about the project or relevant information, making it unclear what the generated text is actually describing.
#
# Given these factors, the overall score for the summary quality would be **0.1**, indicating a very poor evaluation.
# Evaluation explanation: **Score: 0.32**
#
# The generated summary does not cover any of the main points from the reference summary, such as the expected better performance in Q2/2562 due to increased sales of the Sriracha power plant, or the planned investment in a 40 MW solar farm. The generated summary is also very short and lacks clarity, only mentioning that "The key points distilled:" phrase works well for summarization tasks. It does not provide any insight into the actual content being summarized.
#
# The score is low because the generated summary does not demonstrate any understanding of the reference text, and fails to capture even a single key point from it.
# Evaluation explanation: The generated summary is not relevant to the reference article. The generated text discusses summarization tasks, whereas the reference article is an analysis of the oil market, specifically the OPEC meeting outcome.
#
# Score: 0/1
# Evaluation explanation: **Score:** 0.35
#
# The generated summary is too brief to effectively convey the main points of the article. The reference summary covers various aspects, such as KIAT's success in bidding for an LNG transportation contract, its readiness to transition into energy transport services, and its financial performance. In contrast, the generated summary merely states that "The key points distilled" fits best with summarization purpose, which is not a summary at all. The score reflects the vast difference between the two summaries' content coverage, conciseness, and clarity.
# Evaluation explanation: **Score: 0.25**
#
# The generated summary focuses on a specific aspect of the reference summary, namely the prompt "The key points distilled:", without addressing the main topic of the reference text, which is about the challenges faced by Thai startups in raising funding from Series A to B.
#
# While the generated summary is concise and clear, it does not cover any of the content from the reference text. It merely discusses a general concept related to summarization tasks without providing any relevant information or insights.
# Evaluation explanation: **Generated Summary:** A summary of "Key takeaways only" is provided, emphasizing its clarity and conciseness. However, this generated summary does not relate to the article content.
#
# **Reference Summary:** Describes how Chanel and Burberry issued ESG bonds for sustainable development, followed by other companies like Saudi Electricity and Daimler AG. It also mentions Thailand's increasing trend in issuing ESG bonds.
#
# Comparing the two summaries:
#
# * **Content Coverage:** 0 (the generated summary does not relate to the article content)
# * **Conciseness:** 0 (the generated summary is unrelated, while the reference summary conveys meaningful information about ESG bonds and their issuers)
# * **Clarity:** 0.5 (the generated summary is clear in its intention but unrelated to the topic)
#
# **Final Score:** 0/1 (the generated summary fails to provide any relevant or useful information related to the article content)
# Evaluation explanation: The generated summary is a greeting from the author, expressing their enthusiasm for using the phrase "**"The key points distilled:"**" in an article. The reference summary, on the other hand, is a news report about the impact of Yemen's Houthi attacks on Saudi oil facilities on Thai energy stocks.
#
# Comparing the two, I'd give the generated summary a score of 0. This is because it bears no relation to the content or topic of the reference summary.
#
# The generated summary is concise and well-written, but its purpose is entirely unrelated to the topic at hand. The phrase "**"The key points distilled:"**" is not relevant to summarizing the article's content, and the mention of wanting to use this phrase in an article does not align with the actual article being discussed.
#
# In contrast, the reference summary provides a thorough analysis of the situation, discussing the impact on Thai energy stocks and the potential effects on oil prices. It covers key points such as the Saudi oil facility attacks, the expected rise in Thai energy stocks, and the comments from various analysts and experts.
#
# Overall, while the generated summary is well-written, it does not relate to the topic of the reference summary, making its score 0 out of 1.
# Evaluation explanation: The generated summary is not relevant to the reference article at all. The generated text discusses a summarization human prompt, while the reference article appears to be about a company called Asia Capital Group (ACAP) and its plans for issuing bonds.
#
# I would give the generated summary a score of 0 out of 1, as it completely misses the mark on content coverage and relevance.
# Evaluation explanation: The generated summary does not mention the key events of the market (e.g. COVID-19, stock index plummeting) or the fact that trading was halted for two days due to volatility. It also does not provide any information about the buybacks by company executives.
#
# However, it does mention that the author likes the phrase "**"Key takeaways only"**", which seems unrelated to the content of the reference summary.
#
# Given this analysis, I would give the generated summary a score of 0.
#
# Note: It's likely that the generated text is not intended as an actual summary, but rather as a personal preference statement or a way to initiate a conversation about summarization. If so, it wouldn't be relevant to evaluate its quality in terms of content coverage and conciseness.
# Evaluation explanation: **Score:** 0.32
#
#
# The generated summary does not capture the essence of the article, which is about PTTEP's efforts to reduce plastic waste and promote recycling. The reference summary discusses various initiatives by PTTEP, such as Loop Connecting, Drop-Point, and Upcycling Upstyling, to manage plastic waste and promote sustainable practices.
#
#
# The generated summary only mentions a preference for "Key takeaways only" and a casual invitation to provide an article for summarizing. There is no mention of PTTEP's efforts or initiatives, making it a poor representation of the original content.
# Evaluation explanation: Here's my evaluation of the generated summary:
#
# The generated summary is brief and to the point, but it doesn't cover the main content of the reference summary. The generated summary only mentions "The key points distilled:" without providing any actual points or context related to the article.
#
# In contrast, the reference summary provides a detailed explanation of the government's plans to open up the LNG market in Thailand, including the current situation where PTT is the sole importer and the proposed changes to allow private companies to import LNG. The reference summary also mentions the importance of balancing supply and demand, ensuring fair prices, and promoting competition.
#
# Given the significant differences between the two summaries, I would give the generated summary a score of **0** out of 1. The generated summary fails to capture the essence of the article and provides little value compared to the detailed and informative reference summary.
# Evaluation explanation: I'll compare the generated summary with the reference summary.
#
# **Generated Summary:** The CEO of PTT emphasizes extracting crucial information from an article. They're monitoring the drought situation closely, particularly in the eastern region.
#
# **Reference Summary:** (Translates to) Mr. Chanyut Trinunchai, President and CEO of PTT, reported that PTT is closely monitoring the drought situation this year, focusing on the eastern region. The National Water Resources Committee (NWRC) has been assigned to oversee water supply. However, there are still risks, and the amount of rain expected in May-June needs to be monitored. NWRC has proposed a public-private partnership (PPP) for desalination plants, allowing private companies to bid on producing freshwater from seawater.
#
# **Comparison:**
#
# * Content Coverage: The generated summary barely covers any content from the reference summary.
# * Conciseness: The generated summary is concise, but it only focuses on one sentence from the article, while the reference summary highlights several key points.
# * Clarity: The clarity of the generated summary is questionable since it doesn't provide any context or meaning.
#
# **Score:** 0.2/1
#
# The score indicates that the generated summary has almost no resemblance to the actual content of the reference summary and lacks conciseness, clarity, and relevance.
# Evaluation explanation: The generated summary is attempting to summarize the article, but it's not entirely successful. Here's why:
#
# * Content coverage: The generated summary mentions "economic news articles", which is unrelated to the actual topic of the article (gas stations and a company called SCN). It also doesn't mention any specific details from the article.
# * Conciseness: The generated summary is concise, but it lacks any substantial content related to the article. It's more like a general statement about summarizing articles rather than a specific summary.
# * Clarity: The language used in the generated summary is clear and easy to understand.
#
# Overall, I would give this generated summary a score of **0.2** out of 1.0. While it attempts to summarize the article, it fails to cover any relevant content or provide a meaningful summary.
# Epoch 2/4 | Current Score: 2.2970 | Best Score: 26.7450
# Current System Prompt: You are an AI designed to automatically summarize economic news articles by extracting key points an...
# Current Human Prompt: Please condense the key points from the provided article into a concise summary, highlighting the mo...
# --------------------------------------------------
# Optimizing prompts:  50%|█████     | 2/4 [1:01:41<55:34, 1667.37s/it]
# Evaluation explanation: To evaluate the generated summary, I will compare it with the reference summary.
#
# The generated summary is a simple request for a news article, whereas the reference summary is a detailed text discussing the Thai stock market's fundraising efforts. The content coverage of the generated summary is essentially zero, as it doesn't provide any information about the topic.
#
# Given this mismatch, I would score the generated summary a 0 out of 1 in terms of content coverage, conciseness, and clarity, since it fails to deliver even a basic summary of the reference text.
# Evaluation explanation: To evaluate the quality of the generated summary, I will compare it with the reference summary.
#
# The generated response is simply "Please provide me with the news article! I'm ready to analyze it and give you a concise summary of the key economic points. Just paste the text here, and I'll get to work. 😊"
#
# This does not contain any content related to the news article or its analysis, let alone providing a summary.
#
# In comparison, the reference summary is a detailed description of PTT's business strategy, including their New S-Curve plan, expansion into healthcare, and potential synergy with petrochemical businesses.
#
# Given that the generated response does not even attempt to provide a summary, I would give it a score of 0 out of 1.
# Evaluation explanation: To evaluate the quality of the generated summary, I will compare it with the reference summary. Since there is no generated summary provided, I will assume you meant to provide one, but instead, you shared the full article.
#
# However, let's assume a hypothetical generated summary was provided, and we will use the content of the original text as the basis for evaluation.
#
# **Score: 0**
#
# Since there is no generated summary to compare with the reference summary, I cannot provide an accurate score. However, based on the content of the full article, here are some observations:
#
# * The article covers a wide range of economic topics in Thailand, including exports, tourism, investments, and innovations.
# * The text includes various news snippets, such as updates on EEC (Eastern Economic Corridor), SET's youth music competition, and Kinetsu Railway's new travel passes.
#
# If a generated summary were to be provided, I would expect it to condense the main points from the article into a concise, clear, and informative passage. The score of 0 reflects the absence of a generated summary for comparison.
#
# Please provide the generated summary, and I'll be happy to re-evaluate and assign an accurate score!
# Evaluation explanation: To evaluate the quality of the generated summary, I will compare it with the reference summary.
#
# The generated summary does not exist in this conversation. However, based on your request to provide a concise summary of the most important economic points, I can assume that you intended to generate a summary from the given news article.
#
# Since there is no generated summary provided, I will focus on evaluating an hypothetical generated summary against the reference summary.
#
# Assuming the generated summary accurately captures the key points of the news article, I would give it a score based on content coverage, conciseness, and clarity. However, without seeing the actual generated summary, this evaluation cannot be performed precisely.
#
# Let's assume that the generated summary covers about 80% of the content in the reference summary (content coverage: 0.8). The remaining 20% might be minor details or specific figures not crucial to understanding the main points. This assumes some level of information preservation and accurate representation, but without seeing the generated text.
#
# The conciseness of the hypothetical generated summary is assumed to be around 90% (conciseness: 0.9), as it effectively communicates the most important economic points from the article in a compact manner. The clarity of the generated summary is also high, with an estimated score of 95% (clarity: 0.95). This reflects good writing and minimal ambiguity.
#
# Given these hypothetical scores for content coverage, conciseness, and clarity:
#
# Score = (0.8 * Content Coverage) + (0.9 * Conciseness) + (0.95 * Clarity)
# = (0.8 * 0.8) + (0.9 * 0.9) + (0.95 * 0.95)
# ≈ 0.64 + 0.81 + 0.90
# ≈ 2.35
#
# To fit the scale of 0 to 1, we can divide by 2.35:
#
# Final Score ≈ 2.35 / 2.35 ≈ 1.00
#
# Keep in mind that this is an estimated score based on hypothetical assumptions and not a direct evaluation from actual generated summaries.
#
# Score: 1 (Perfect)
# Evaluation explanation: **Content Coverage:** 0.3 (The generated summary only mentions the need for a news article, whereas the reference summary discusses a specific company's development of a battery technology and its potential market expansion.)
#
# **Conciseness:** 0.2 (The generated summary is vague and lacks any meaningful content, whereas the reference summary provides a concise overview of the topic with relevant details.)
#
# **Clarity:** 0.1 (The generated summary is unclear and doesn't provide any information about the topic, whereas the reference summary explains the concept clearly and effectively.)
#
# Overall Score: **0.2/1**
#
# Reasoning: The generated summary does not address the content at all, while the reference summary provides a detailed explanation of the battery technology development by GPSC.
# Evaluation explanation: Here's the comparison between the generated summary and the reference summary:
#
# The generated summary does not exist, as it was an empty request for a news article. However, I can still provide a score based on the context.
#
# Score: 0 (no summary to compare)
#
# However, if we consider the conversation itself, I can evaluate the quality of the conversation partner's response (you). Since this is a hypothetical scenario, I'll provide a neutral score.
#
# The conversation started with an empty request for a news article, which indicates a lack of content to work with. However, your response to "Please provide me with the news article! I'm ready to analyze it and give you a concise summary of the key economic points." is a polite and engaging way to start a conversation.
#
# In this case, the score would be:
#
# Score: 0 (no summary to compare)
#
# However, considering your willingness to engage in a hypothetical scenario, I can still provide a neutral score.
#
# Neutral Score: 0.5
# Evaluation explanation: Here's the comparison:
#
# The generated summary does not attempt to summarize the news article, instead asking for the article itself. This is not a summary, but rather an expectation of receiving information. As such, there is no content coverage, conciseness, or clarity to evaluate.
#
# Score: 0
# Evaluation explanation: The generated summary is "Please provide me with the news article! I'm ready to analyze it and give you a concise summary of the key economic points. 😊"
#
# The reference summary discusses the real estate association in Chonburi province, Thailand, expressing support for the government's plan to develop 10,000 rai (1,562 hectares) of land around the high-speed train station and the new city of Sri Racha-Chon Buri.
#
# Comparing the two summaries, I would give a score of **0** out of 1. The generated summary is unrelated to the reference summary and lacks any connection to the topic at hand. It appears to be a humorous response instead of an actual attempt to summarize the news article.
# Evaluation explanation: **Score: 0.3**
#
# The generated summary fails to cover the main points or arguments presented in the reference article. The key economic issue discussed, the main points or arguments presented, significant findings, data, or statistics mentioned, and the overall conclusion or takeaway message are all missing from the generated summary.
#
# The generated summary is too vague and does not provide any specific information about the company's performance, investments, or plans for increasing capital. It only mentions a general statement about summarizing the news article without providing any actual content.
#
# To improve the score, the generated summary should include specific details about the company's economic situation, such as its revenue growth, investment plans, and capital increase targets. The summary should also provide clear and concise information about the main points or arguments presented in the reference article.
# Evaluation explanation: To evaluate the generated summary, I will compare it with the reference summary. Here's my analysis:
#
# **Content coverage**: The generated summary does not cover any of the main points from the reference summary. It seems to be a generic response without any relation to the actual news article.
#
# **Conciseness**: The generated summary is too long and vague, providing no specific information about the topic.
#
# **Clarity**: The language used in the generated summary is unclear and does not provide any useful insights or analysis.
#
# Based on these factors, I would give the generated summary a score of **0.2**, indicating that it is far from perfect. The lack of content coverage, conciseness, and clarity makes it an ineffective summary.
# Evaluation explanation: Here's my evaluation of the generated summary:
#
# **Score:** 0.3 (out of 1)
#
# The generated summary fails to capture the essence of the news article, focusing instead on a generic introduction that doesn't convey any information about the content of the article. The reference summary provides specific details about the company KIAT winning a contract for transporting LNG from Mab Ta Phut to Ratchaburi province, whereas the generated summary is vague and lacks substance.
#
# The generated summary also contains phrases like "key economic points" and "takeaways", which are not present in the reference summary. This suggests that the generated summary is more focused on asking questions than providing a concise and informative summary.
#
# Overall, the generated summary falls short of being a useful summary due to its lack of content coverage, conciseness, and clarity.
# Evaluation explanation: **Score: 0.5**
#
# The generated summary is incomplete and does not capture the main points of the reference summary. Here's a brief explanation:
#
# * **Content coverage**: The generated summary only mentions that a startup founder mentioned about fundraising, but it doesn't provide any specific information or quotes from the founders in the article.
# * **Conciseness**: The generated summary is too short and doesn't convey the main ideas of the article.
# * **Clarity**: The language used in the generated summary is unclear and not specific to the topic.
#
# ...
# * Conciseness: The generated summary is concise but lacks specific details and comparisons to the reference summary.
# * Clarity: The language used in the generated summary is clear, but it fails to convey the main idea of the reference summary.
#
# The score is relatively low because the generated summary does not capture the essence of the reference summary, which provides specific information about the possible outcomes from OPEC's meeting and their potential impact on the stock prices of PTT and PTTEP.
# Evaluation explanation: To evaluate the generated summary, I will compare it with the reference summary. However, you didn't provide the text of the article for me to summarize.
#
# Please provide the news article text, and I'll generate a summary, then compare it with the reference summary provided. This will allow me to calculate an accuracy score between 0 and 1.
#
# Once I receive the article text, I'll proceed with evaluating the generated summary against the reference one, considering factors such as content coverage, conciseness, and clarity, before providing the final score.
# Evaluation explanation: Here's my evaluation of the generated summary:
#
# The generated summary is "Please provide me with the news article you would like summarized. I'm ready to condense it into a concise and informative summary for you!" This summary does not attempt to summarize the content of the reference summary, but rather asks for the input text.
#
# Content coverage: 0 (does not cover any part of the reference summary)
#
# Conciseness: 1 (is very brief, which is good)
#
# Clarity: N/A (does not provide any clear summary or information)
#
# Score: 0/1 (this is not a valid summary)
#
# I would suggest generating a new attempt at summarizing the provided text.
# Evaluation explanation: To evaluate the quality of the generated summary, I will compare it with the reference summary. Here's my analysis:
#
# The generated summary asks for the news article text to be provided, which is an incomplete sentence that doesn't summarize anything. This suggests a lack of content coverage.
#
# In contrast, the reference summary provides detailed information about the topic, including specific examples of companies (Chanel and Burberry) that have issued ESG bonds, as well as statistics on the growing trend of ESG bond issuance in Thailand.
#
# Based on this comparison, I would give the generated summary a score of 0. The reason is that it doesn't provide any content, whereas the reference summary covers all relevant aspects of the topic with clarity and conciseness.
#
# Score: 0/1
# Evaluation explanation: Here's a comparison of the generated summary with the reference summary:
#
# **Content Coverage:** The generated summary only mentions that the oil price has increased due to the Yemeni attack, but it does not provide any specific details about the Thai energy stocks or the government's response. (Score: 0.4)
#
# **Conciseness:** The generated summary is too brief and lacks essential information. It only consists of a single sentence without providing any context or supporting details. (Score: 0.3)
#
# **Clarity:** Unfortunately, the generated summary is not clear at all. It appears to be a random statement without any connection to the original article. (Score: 0.2)
#
# Overall Score: 0.33/1
#
# The score indicates that the generated summary falls short of providing an accurate and informative summary of the original article. It lacks essential content, is not concise, and is unclear.
# Evaluation explanation: The generated summary is "Please provide me with the news article you would like summarized. I'm ready to condense it into a concise summary for you!". However, this response does not summarize the content of the reference article at all.
#
# In comparison to the reference summary, which provides specific details about Asia Capital Group's plans and financial performance, the generated summary is essentially empty. It lacks content coverage, conciseness, and clarity.
#
# Therefore, I would give a score of 0 out of 1.
# Evaluation explanation: **Generated Summary:** Unfortunately, the generated summary is not provided. I'll assume it's a request to provide a summary of the news article.
#
# **Reference Summary:** The reference summary is a detailed report on the Thai stock market situation from March 9-13, 2020, which includes information about the index drop, trading halt, and company executives buying shares.
#
# **Comparison:**
#
# The generated summary is not provided, so I'll only compare the quality of a potential generated summary with the reference summary.
#
# Assuming a perfect generated summary would cover all key points from the reference summary, including:
#
# 1. The Thai stock market's volatile situation due to COVID-19 concerns.
# 2. The index drop by 17.26% in one week.
# 3. The trading halt for two consecutive days.
# 4. The significant drop in the index (450.93 points) and its current level (1,128.91).
# 5. Information about executives buying shares.
#
# Given that no generated summary is provided, I'll assume an average score of 0.5, which reflects the lack of content coverage. However, if a generated summary were to cover all these key points accurately and concisely, it would likely receive a higher score.
#
# **Score:** 0.5 (due to the absence of a generated summary)
# Evaluation explanation: The generated summary is:
#
# Please provide me with the news article you would like summarized. I'm ready to condense it into a concise and informative summary for you!
#
# And the reference summary is:
#
# วิกฤติกลายเป็นโอกาสสำหรับอุตฯพลาสติก เมื่อสถานการณ์การแพร่ระบาดโรคโควิด-19 และการใช้ชีวิตวิถีใหม่ อย่างการสั่งซื้ออาหารเดลิเวอรี่ ทำให้มีกล่องอาหารเดลิเวอรี่เพิ่มมากถึง 15% ต่อวัน ส่งผลให้การใช้พลาสติกประเภทครั้งเดียวทิ้งเพิ่มขึ้น
#
# การบริหารจัดการขยะพลาสติกของ GC เป็นหนึ่งในส่วนสำคัญในการเร่งให้เกิดการพัฒนาวงจรรีไซเคิล (Recycle) ได้อย่างสมบูรณ์แบบ โดยใช้แพลตฟอร์ม Loop Connecting และ โครงการ ส่งพลาสติกกลับบ้าน
#
# The generated summary does not address the main topic of the reference summary, which is about a company's efforts to manage plastic waste during the COVID-19 pandemic. The content coverage score is therefore 0.
#
# However, if we ignore the content and focus on conciseness and clarity, the generated summary is a single sentence that asks for the news article, making it a perfect example of brevity. But since this doesn't contribute to understanding the topic at hand, I will not give credit for that.
#
# Overall score: 0/1
# Evaluation explanation: Here's my evaluation of the generated summary:
#
# The generated summary, "Please provide me with the news article you'd like me to summarize. I'm ready to condense it into a concise and informative summary for you!", is not related to the reference summary at all. It appears to be a request for input from the user.
#
# Compared to the reference summary, which discusses the opening of the natural gas market in Thailand and the planned redistribution of LNG imports, the generated summary lacks content coverage and conciseness entirely. The clarity is also non-existent due to its irrelevance to the topic.
#
# Score: 0/1
#
# Note that this score would be the same even if you were to compare it to an arbitrary news article, since the generated summary does not relate to any news article whatsoever.
# Evaluation explanation: To evaluate the quality of the generated summary, I compare it with the reference summary. Here's my analysis:
#
# The generated summary starts by asking for a news article to summarize, which is not present in the reference summary. This means that the generated summary does not accurately represent the content of the original text.
#
# However, if we ignore this initial statement and only consider the rest of the generated summary, it seems to cover some key points from the reference summary, such as:
#
# * PTT's focus on following the water shortage situation
# * The proposal to sell water production rights through PPP (Public-Private Partnership) model
# * PTT's investment plans for Mab Ta Phut and Laem Chabang seaports
# * The company's shift in exports from China to other markets
#
# However, the generated summary lacks clarity and conciseness. It seems to be fragmented and does not provide a clear overview of the main points.
#
# Score: 0.4/1 (40%)
#
# The score is low due to the initial statement asking for a news article, which is not present in the reference summary, and the lack of clarity and conciseness in the rest of the generated summary.
# Evaluation explanation: Let's compare the generated summary with the reference summary.
#
# The generated summary is essentially a request for a news article to be summarized, while the reference summary is an actual Thai-language news article about a company signing a contract with PTT. Given this discrepancy, it's impossible for the generated summary to match the content coverage of the reference summary.
#
# In terms of conciseness and clarity, the generated summary is also lacking, as it does not provide any information that can be compared to the reference summary.
#
# Given these factors, I would assign a score of 0 out of 1.
# Epoch 4/4 | Current Score: 102.7000 | Best Score: 102.7000
# Current System Prompt: Summarize this news article about economic topics for me....
# Current Human Prompt: Take a lengthy article and condense it into a concise summary, highlighting the most critical inform...
# --------------------------------------------------
# Optimizing prompts: 100%|██████████| 4/4 [1:25:44<00:00, 1286.13s/it]
# Best System Prompt: Summarize this news article about economic topics for me.
#
# Best Human Prompt: Take a lengthy article and condense it into a concise summary, highlighting the most critical information, key findings, or main takeaways in 1-2 paragraphs at most.
#
# Best Score: 102.7000
#
# Prompt History:
# Epoch 1:
# System Prompt: You are an AI specialized in extractive summarization for economic news articles.
# Human Prompt: Your task is to summarize the key content from the given news article. Follow these guidelines:
#     1. Summarize the content in Thai.
#     2. Use 	 at the beginning of each paragraph to create indentation.
#     3. DO NOT leave blank lines between paragraphs. All paragraphs must be continuous with no blank lines.
#     4. Focus on main points and important secondary points.
#     5. Provide explanations of the article’s key topics without going into too much detail.
#     6. Preserve all proper nouns such as names of people, companies, or organizations.
#     7. Use 2-3 key sentences from the original article for each point.
#     8. Maintain the original meaning and context.
#     9. Arrange the content in the same order as presented in the original article.
#     10. Reduce redundancy by combining similar points or information.
#     11. DO NOT include any examples in the summary.
#
#     IMPORTANT:
#     - DO NOT include any examples or case studies in the summary. Focus only on the main points and key information.
#
#     Article to summarize:
#     {text}
# Score: 26.7450
# --------------------------------------------------
# Epoch 2:
# System Prompt: You are an AI designed to automatically summarize economic news articles by extracting key points and condensing them into concise summaries. Here is a short phrase that you can use in a summarization system prompt:
#
# "Summarize the main points"
#
# However, if you're looking for something more specific or context-dependent, I'd be happy to try and suggest some alternatives!
#
# Alternatively, here are a few other options:
#
# * "Give me the gist"
# * "Provide a brief overview"
# * "Simplify and summarize"
# * "Key takeaways only"
# * "The main points in a nutshell"
#
# Let me know if you have any specific requirements or context that might help me suggest a more tailored phrase!
# Human Prompt: Please condense the key points from the provided article into a concise summary, highlighting the most important information and omitting trivial details. Here are a few options:
#
# 1. "In their own words..."
# 2. "The essence of the conversation is..."
# 3. "A summary in brief:"
# 4. "The key points distilled:"
# 5. "What matters most here is..."
#
# Which one do you think fits best with your summarization human prompt?
# Score: 2.2970
# --------------------------------------------------
# Epoch 3:
# System Prompt: Given a news article about economic topics, I'd like to summarize it for you in a concise manner.
# Human Prompt: Take a lengthy article and distill it down to the most important information, highlighting the main ideas, findings, or conclusions in a concise manner.
# Score: 5.7350
# --------------------------------------------------
# Epoch 4:
# System Prompt: Summarize this news article about economic topics for me.
# Human Prompt: Take a lengthy article and condense it into a concise summary, highlighting the most critical information, key findings, or main takeaways in 1-2 paragraphs at most.
# Score: 102.7000
# --------------------------------------------------
# [{'epoch': 1, 'system_prompt': 'You are an AI specialized in extractive summarization for economic news articles.', 'human_prompt': 'Your task is to summarize the key content from the given news article. Follow these guidelines:\n    1. Summarize the content in Thai.\n    2. Use \t at the beginning of each paragraph to create indentation.\n    3. DO NOT leave blank lines between paragraphs. All paragraphs must be continuous with no blank lines.\n    4. Focus on main points and important secondary points.\n    5. Provide explanations of the article’s key topics without going into too much detail.\n    6. Preserve all proper nouns such as names of people, companies, or organizations.\n    7. Use 2-3 key sentences from the original article for each point.\n    8. Maintain the original meaning and context.\n    9. Arrange the content in the same order as presented in the original article.\n    10. Reduce redundancy by combining similar points or information.\n    11. DO NOT include any examples in the summary.\n\n    IMPORTANT: \n    - DO NOT include any examples or case studies in the summary. Focus only on the main points and key information.\n\n    Article to summarize:\n    {text}', 'score': 26.744999999999997}, {'epoch': 2, 'system_prompt': 'You are an AI designed to automatically summarize economic news articles by extracting key points and condensing them into concise summaries. Here is a short phrase that you can use in a summarization system prompt:\n\n"Summarize the main points"\n\nHowever, if you\'re looking for something more specific or context-dependent, I\'d be happy to try and suggest some alternatives!\n\nAlternatively, here are a few other options:\n\n* "Give me the gist"\n* "Provide a brief overview"\n* "Simplify and summarize"\n* "Key takeaways only"\n* "The main points in a nutshell"\n\nLet me know if you have any specific requirements or context that might help me suggest a more tailored phrase!', 'human_prompt': 'Please condense the key points from the provided article into a concise summary, highlighting the most important information and omitting trivial details. Here are a few options:\n\n1. "In their own words..."\n2. "The essence of the conversation is..."\n3. "A summary in brief:"\n4. "The key points distilled:"\n5. "What matters most here is..."\n\nWhich one do you think fits best with your summarization human prompt?', 'score': 2.297}, {'epoch': 3, 'system_prompt': "Given a news article about economic topics, I'd like to summarize it for you in a concise manner.", 'human_prompt': 'Take a lengthy article and distill it down to the most important information, highlighting the main ideas, findings, or conclusions in a concise manner.', 'score': 5.734999999999999}, {'epoch': 4, 'system_prompt': 'Summarize this news article about economic topics for me.', 'human_prompt': 'Take a lengthy article and condense it into a concise summary, highlighting the most critical information, key findings, or main takeaways in 1-2 paragraphs at most.', 'score': 102.70000000000002}]

# %%
optimize
# Out:
# [{'epoch': 1,
#   'system_prompt': 'You are an AI specialized in extractive summarization for economic news articles.',
#   'human_prompt': 'Your task is to summarize the key content from the given news article. Follow these guidelines:\n    1. Summarize the content in Thai.\n    2. Use \t at the beginning of each paragraph to create indentation.\n    3. DO NOT leave blank lines between paragraphs. All paragraphs must be continuous with no blank lines.\n    4. Focus on main points and important secondary points.\n    5. Provide explanations of the article’s key topics without going into too much detail.\n    6. Preserve all proper nouns such as names of people, companies, or organizations.\n    7. Use 2-3 key sentences from the original article for each point.\n    8. Maintain the original meaning and context.\n    9. Arrange the content in the same order as presented in the original article.\n    10. Reduce redundancy by combining similar points or information.\n    11. DO NOT include any examples in the summary.\n\n    IMPORTANT: \n    - DO NOT include any examples or case studies in the summary. Focus only on the main points and key information.\n\n    Article to summarize:\n    {text}',
#   'score': 26.744999999999997},
#  {'epoch': 2,
#   'system_prompt': 'You are an AI designed to automatically summarize economic news articles by extracting key points and condensing them into concise summaries. Here is a short phrase that you can use in a summarization system prompt:\n\n"Summarize the main points"\n\nHowever, if you\'re looking for something more specific or context-dependent, I\'d be happy to try and suggest some alternatives!\n\nAlternatively, here are a few other options:\n\n* "Give me the gist"\n* "Provide a brief overview"\n* "Simplify and summarize"\n* "Key takeaways only"\n* "The main points in a nutshell"\n\nLet me know if you have any specific requirements or context that might help me suggest a more tailored phrase!',
#   'human_prompt': 'Please condense the key points from the provided article into a concise summary, highlighting the most important information and omitting trivial details. Here are a few options:\n\n1. "In their own words..."\n2. "The essence of the conversation is..."\n3. "A summary in brief:"\n4. "The key points distilled:"\n5. "What matters most here is..."\n\nWhich one do you think fits best with your summarization human prompt?',
#   'score': 2.297},
#  {'epoch': 3,
#   'system_prompt': "Given a news article about economic topics, I'd like to summarize it for you in a concise manner.",
#   'human_prompt': 'Take a lengthy article and distill it down to the most important information, highlighting the main ideas, findings, or conclusions in a concise manner.',
#   'score': 5.734999999999999},
#  {'epoch': 4,
#   'system_prompt': 'Summarize this news article about economic topics for me.',
#   'human_prompt': 'Take a lengthy article and condense it into a concise summary, highlighting the most critical information, key findings, or main takeaways in 1-2 paragraphs at most.',
#   'score': 102.70000000000002}]
